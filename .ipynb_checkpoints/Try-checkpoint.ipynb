# %%
import requests  

import pandas as pd 
from pandas.io.json import json_normalize

import numpy as np

from geopy.geocoders import Nominatim 
import geocoder 

import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans

import folium

import matplotlib.pyplot as plt

# %%
CLIENT_ID = 'IRNDM0FF5HHW4I3AACXII3TW5ZOUJOUNK0QHJLFFSJ5ITPZE' # your Foursquare ID
CLIENT_SECRET = 'THW2UZ4OV0ISDLZW4V4OT5C0UWQQK10LZTJQ1QJKFTZ2KUZJ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: IRNDM0FF5HHW4I3AACXII3TW5ZOUJOUNK0QHJLFFSJ5ITPZE
# CLIENT_SECRET:THW2UZ4OV0ISDLZW4V4OT5C0UWQQK10LZTJQ1QJKFTZ2KUZJ

# %%
address = 'Bangkok'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
# Out:
# The geograpical coordinate of Bangkok are 13.7544238, 100.4930399.

# %%
LIMIT = 100
radius = 500

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)

# %%
results = requests.get(url).json()["response"]['groups'][0]['items']
results
# Out:
# [{'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4b0587f9f964a52001aa22e3',
#    'name': 'Temple of the Emerald Buddha (วัดพระศรีรัตนศาสดาราม (วัดพระแก้ว))',
#    'location': {'address': 'Na Phra Lan Rd',
#     'crossStreet': 'Maha Rat Rd',
#     'lat': 13.751734643691861,
#     'lng': 100.49265146255493,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.751734643691861,
#       'lng': 100.49265146255493}],
#     'distance': 302,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'city': 'พระนคร',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['Na Phra Lan Rd (Maha Rat Rd)',
#      'พระนคร',
#      'กรุงเทพมหานคร 10200',
#      'ประเทศไทย']},
#    'categories': [{'id': '52e81612bcbc57f1066b7a3e',
#      'name': 'Buddhist Temple',
#      'pluralName': 'Buddhist Temples',
#      'shortName': 'Buddhist Temple',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4b0587f9f964a52001aa22e3-0'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5010afc9e4b090757f48c99a',
#    'name': 'Café VeloDome (คาเฟ่ เวโลโดม)',
#    'location': {'address': 'Phra Chan Rd.',
#     'lat': 13.755757,
#     'lng': 100.492017,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.755757,
#       'lng': 100.492017}],
#     'distance': 185,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'city': 'พระนคร',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['Phra Chan Rd.',
#      'พระนคร',
#      'กรุงเทพมหานคร 10200',
#      'ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d16d941735',
#      'name': 'Café',
#      'pluralName': 'Cafés',
#      'shortName': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5010afc9e4b090757f48c99a-1'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c029d3c302295213c6fde81',
#    'name': 'Thokkathan-Mother Earth Squeezing Her Hair (พระแม่ธรณีบีบมวยผม อุทกทาน)',
#    'location': {'address': 'Ratchadamnoen Nai Rd.',
#     'crossStreet': 'Rachini Rd.',
#     'lat': 13.756601843910255,
#     'lng': 100.49476730464075,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.756601843910255,
#       'lng': 100.49476730464075}],
#     'distance': 306,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'city': 'พระนคร',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['Ratchadamnoen Nai Rd. (Rachini Rd.)',
#      'พระนคร',
#      'กรุงเทพมหานคร 10200',
#      'ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d131941735',
#      'name': 'Spiritual Center',
#      'pluralName': 'Spiritual Centers',
#      'shortName': 'Spiritual',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c029d3c302295213c6fde81-2'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4ceb69b1d27560fca3439b3a',
#    'name': 'The Grand Palace (พระบรมมหาราชวัง)',
#    'location': {'address': 'Na Phra Lan Rd',
#     'crossStreet': 'Maha Rat Rd & Sanam Chai Rd',
#     'lat': 13.751813689290364,
#     'lng': 100.49117576966269,
#     'distance': 353,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'city': 'พระนคร',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['Na Phra Lan Rd (Maha Rat Rd & Sanam Chai Rd)',
#      'พระนคร',
#      'กรุงเทพมหานคร 10200',
#      'ประเทศไทย']},
#    'categories': [{'id': '52e81612bcbc57f1066b7a14',
#      'name': 'Palace',
#      'pluralName': 'Palaces',
#      'shortName': 'Palace',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4ceb69b1d27560fca3439b3a-3'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4d9bdddd7ae5548198a34174',
#    'name': 'Prasat Phra Thep Bidon (ปราสาทพระเทพบิดร)',
#    'location': {'address': 'Temple of the Emerald Buddha',
#     'lat': 13.751606,
#     'lng': 100.49272,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.751606,
#       'lng': 100.49272}],
#     'distance': 315,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'city': 'พระบรมมหาราชวัง',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['Temple of the Emerald Buddha',
#      'พระบรมมหาราชวัง',
#      'กรุงเทพมหานคร 10200',
#      'ประเทศไทย']},
#    'categories': [{'id': '52e81612bcbc57f1066b7a14',
#      'name': 'Palace',
#      'pluralName': 'Palaces',
#      'shortName': 'Palace',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4d9bdddd7ae5548198a34174-4'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '50dfa3fbe4b0eb1fe51ec7ef',
#    'name': 'Siwamokhaphiman Hall (พระที่นั่งศิวโมกขพิมาน)',
#    'location': {'address': 'Bangkok National Museum',
#     'lat': 13.757516,
#     'lng': 100.49214,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.757516,
#       'lng': 100.49214}],
#     'distance': 357,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'neighborhood': 'Phra Borom Maha Ratchawang',
#     'city': 'พระนคร',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['Bangkok National Museum',
#      'พระนคร',
#      'กรุงเทพมหานคร 10200',
#      'ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d181941735',
#      'name': 'Museum',
#      'pluralName': 'Museums',
#      'shortName': 'Museum',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-50dfa3fbe4b0eb1fe51ec7ef-5'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4d20393a0901721e6ffc90a5',
#    'name': 'พระที่นั่งพุทไธสวรรย์',
#    'location': {'address': 'Bangkok National Museum',
#     'lat': 13.7578945,
#     'lng': 100.4921,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.7578945,
#       'lng': 100.4921}],
#     'distance': 399,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'neighborhood': 'Phra Borom Maha Ratchawang',
#     'city': 'พระนคร',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['Bangkok National Museum',
#      'พระนคร',
#      'กรุงเทพมหานคร 10200',
#      'ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d190941735',
#      'name': 'History Museum',
#      'pluralName': 'History Museums',
#      'shortName': 'History Museum',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4d20393a0901721e6ffc90a5-6'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4bb04db0f964a52057403ce3',
#    'name': 'Wat Mahathat Yuwarajarangsarit Rajaworamahavihara (วัดมหาธาตุยุวราชรังสฤษฎิ์ราชวรมหาวิหาร)',
#    'location': {'address': 'Maha Rat Rd',
#     'lat': 13.755066642937557,
#     'lng': 100.49048941692712,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.755066642937557,
#       'lng': 100.49048941692712}],
#     'distance': 284,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'city': 'พระบรมมหาราชวัง',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['Maha Rat Rd',
#      'พระบรมมหาราชวัง',
#      'กรุงเทพมหานคร 10200',
#      'ประเทศไทย']},
#    'categories': [{'id': '52e81612bcbc57f1066b7a3e',
#      'name': 'Buddhist Temple',
#      'pluralName': 'Buddhist Temples',
#      'shortName': 'Buddhist Temple',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4bb04db0f964a52057403ce3-7'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4bda4a3e3904a593c40d469e',
#    'name': 'Bangkok National Museum (พิพิธภัณฑสถานแห่งชาติ พระนคร)',
#    'location': {'address': 'Na Phra That Rd',
#     'lat': 13.757215438529597,
#     'lng': 100.49243957896135,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.757215438529597,
#       'lng': 100.49243957896135}],
#     'distance': 317,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'city': 'พระนคร',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['Na Phra That Rd',
#      'พระนคร',
#      'กรุงเทพมหานคร 10200',
#      'ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d190941735',
#      'name': 'History Museum',
#      'pluralName': 'History Museums',
#      'shortName': 'History Museum',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4bda4a3e3904a593c40d469e-8'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4b8a06e7f964a520545c32e3',
#    'name': 'R-Roy Garlic Bread (ขนมปังกระเทียมร้านอร่อย)',
#    'location': {'address': 'Maha Rat Rd.',
#     'crossStreet': 'Phra Chan Rd.',
#     'lat': 13.756171738063438,
#     'lng': 100.48970096348074,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.756171738063438,
#       'lng': 100.48970096348074}],
#     'distance': 410,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'city': 'พระนคร',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['Maha Rat Rd. (Phra Chan Rd.)',
#      'พระนคร',
#      'กรุงเทพมหานคร 10200',
#      'ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d16a941735',
#      'name': 'Bakery',
#      'pluralName': 'Bakeries',
#      'shortName': 'Bakery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4b8a06e7f964a520545c32e3-9'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4f83c20ce4b0443298bee012',
#    'name': 'Tha Prachan (ท่าพระจันทร์)',
#    'location': {'lat': 13.756201088298637,
#     'lng': 100.48968227270649,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.756201088298637,
#       'lng': 100.48968227270649}],
#     'distance': 413,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'city': 'พระนคร',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['พระนคร', 'กรุงเทพมหานคร 10200', 'ประเทศไทย']},
#    'categories': [{'id': '4f2a25ac4b909258e854f55f',
#      'name': 'Neighborhood',
#      'pluralName': 'Neighborhoods',
#      'shortName': 'Neighborhood',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4f83c20ce4b0443298bee012-10'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '530f18ed498e27ad09ba8272',
#    'name': 'Tha Maharaj (ท่ามหาราช)',
#    'location': {'address': '1/11 Trok Maha That',
#     'lat': 13.754878037656617,
#     'lng': 100.48877081229503,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.754878037656617,
#       'lng': 100.48877081229503}],
#     'distance': 464,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'city': 'พระนคร',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['1/11 Trok Maha That',
#      'พระนคร',
#      'กรุงเทพมหานคร 10200',
#      'ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d1fd941735',
#      'name': 'Shopping Mall',
#      'pluralName': 'Shopping Malls',
#      'shortName': 'Mall',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-530f18ed498e27ad09ba8272-11'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '548edbfd498e2d4a137c8c1c',
#    'name': 'Starbucks (สตาร์บัคส์)',
#    'location': {'address': 'Tha Maharaj',
#     'crossStreet': '1st Fl, #C1-01',
#     'lat': 13.754670359216373,
#     'lng': 100.48869395790238,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.754670359216373,
#       'lng': 100.48869395790238}],
#     'distance': 470,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'neighborhood': 'Phra Borom Maha Ratchawang',
#     'city': 'พระนคร',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['Tha Maharaj (1st Fl, #C1-01)',
#      'พระนคร',
#      'กรุงเทพมหานคร 10200',
#      'ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-548edbfd498e2d4a137c8c1c-12'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c8d867af87e224bb28c3e05',
#    'name': 'Queen Sirikit Museum of Textiles (พิพิธภัณฑ์ผ้า หอรัษฎากรพิพัฒน์ ในสมเด็จพระนางเจ้าสิริกิติ์ พระบรมราชินีนาถ)',
#    'location': {'address': 'Rasadakornpipat Building',
#     'crossStreet': 'The Grand Palace',
#     'lat': 13.751957,
#     'lng': 100.49092,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.751957,
#       'lng': 100.49092}],
#     'distance': 357,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'neighborhood': 'Phra Borom Maha Ratchawang',
#     'city': 'พระนคร',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['Rasadakornpipat Building (The Grand Palace)',
#      'พระนคร',
#      'กรุงเทพมหานคร 10200',
#      'ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d18f941735',
#      'name': 'Art Museum',
#      'pluralName': 'Art Museums',
#      'shortName': 'Art Museum',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c8d867af87e224bb28c3e05-13'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '51d4bb6d498ea5b1fe6ec103',
#    'name': 'Café Amazon (คาเฟ่ อเมซอน)',
#    'location': {'address': 'Ministry of Defence',
#     'lat': 13.75241331553434,
#     'lng': 100.49415432574492,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.75241331553434,
#       'lng': 100.49415432574492}],
#     'distance': 254,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'city': 'พระนคร',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['Ministry of Defence',
#      'พระนคร',
#      'กรุงเทพมหานคร 10200',
#      'ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-51d4bb6d498ea5b1fe6ec103-14'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '55002446498e94585e4c98e5',
#    'name': 'After You (อาฟเตอร์ ยู)',
#    'location': {'address': 'Tha Maharaj',
#     'crossStreet': '1st Fl, #03',
#     'lat': 13.754922376930377,
#     'lng': 100.48871767001823,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.754922376930377,
#       'lng': 100.48871767001823}],
#     'distance': 470,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'city': 'พระนคร',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['Tha Maharaj (1st Fl, #03)',
#      'พระนคร',
#      'กรุงเทพมหานคร 10200',
#      'ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d1d0941735',
#      'name': 'Dessert Shop',
#      'pluralName': 'Dessert Shops',
#      'shortName': 'Desserts',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-55002446498e94585e4c98e5-15'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4d144003401db60c6c04d7a4',
#    'name': 'นิวย่งฮั้ว โภชนา',
#    'location': {'address': 'Phra Chan Rd.',
#     'lat': 13.756221,
#     'lng': 100.489486,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.756221,
#       'lng': 100.489486}],
#     'distance': 433,
#     'postalCode': '10100',
#     'cc': 'TH',
#     'city': 'พระนคร',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['Phra Chan Rd.',
#      'พระนคร',
#      'กรุงเทพมหานคร 10100',
#      'ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d145941735',
#      'name': 'Chinese Restaurant',
#      'pluralName': 'Chinese Restaurants',
#      'shortName': 'Chinese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4d144003401db60c6c04d7a4-16'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5493fcff498ecc2164b93e85',
#    'name': 'Favour Café',
#    'location': {'address': 'Tha Maharaj',
#     'crossStreet': '1st Fl,',
#     'lat': 13.754418135459991,
#     'lng': 100.48901740724114,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.754418135459991,
#       'lng': 100.48901740724114}],
#     'distance': 434,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'city': 'พระนคร',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['Tha Maharaj (1st Fl,)',
#      'พระนคร',
#      'กรุงเทพมหานคร 10200',
#      'ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d16d941735',
#      'name': 'Café',
#      'pluralName': 'Cafés',
#      'shortName': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5493fcff498ecc2164b93e85-17'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '55f025a4498e38c02aac273d',
#    'name': 'Noa Noa Cafe (โนอะโนอะคาเฟ่)',
#    'location': {'address': 'Tha Maharaj',
#     'crossStreet': '2nd Fl.',
#     'lat': 13.754620186987838,
#     'lng': 100.48872712206395,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.754620186987838,
#       'lng': 100.48872712206395}],
#     'distance': 466,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'city': 'พระนคร',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['Tha Maharaj (2nd Fl.)',
#      'พระนคร',
#      'กรุงเทพมหานคร 10200',
#      'ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d111941735',
#      'name': 'Japanese Restaurant',
#      'pluralName': 'Japanese Restaurants',
#      'shortName': 'Japanese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-55f025a4498e38c02aac273d-18'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4d07ae37acb32d43d6d6a44b',
#    'name': 'Borom Phiman Mansion (พระที่นั่งบรมพิมาน)',
#    'location': {'address': 'The Grand Palace',
#     'lat': 13.750489295912226,
#     'lng': 100.49297332763672,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.750489295912226,
#       'lng': 100.49297332763672}],
#     'distance': 438,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'neighborhood': 'Phra Borom Maha Ratchawang',
#     'city': 'พระนคร',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['The Grand Palace',
#      'พระนคร',
#      'กรุงเทพมหานคร 10200',
#      'ประเทศไทย']},
#    'categories': [{'id': '4deefb944765f83613cdba6e',
#      'name': 'Historic Site',
#      'pluralName': 'Historic Sites',
#      'shortName': 'Historic Site',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4d07ae37acb32d43d6d6a44b-19'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4b0587fcf964a520e8aa22e3',
#    'name': 'The National Theatre (โรงละครแห่งชาติ)',
#    'location': {'address': '2 Rachini Rd.',
#     'crossStreet': 'near Somdet Phra Pinklao Bridge',
#     'lat': 13.758806021120995,
#     'lng': 100.49286147385915,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.758806021120995,
#       'lng': 100.49286147385915}],
#     'distance': 488,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'city': 'พระนคร',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['2 Rachini Rd. (near Somdet Phra Pinklao Bridge)',
#      'พระนคร',
#      'กรุงเทพมหานคร 10200',
#      'ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d137941735',
#      'name': 'Theater',
#      'pluralName': 'Theaters',
#      'shortName': 'Theater',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4b0587fcf964a520e8aa22e3-20'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4e71841945dd2c5c1a3e3665',
#    'name': 'Thai Tham (ลูกชิ้น-มันสมองหมู ไทยทำ)',
#    'location': {'address': 'Phraeng Phuthon Rd',
#     'lat': 13.75180880641601,
#     'lng': 100.4967156272417,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.75180880641601,
#       'lng': 100.4967156272417}],
#     'distance': 492,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'neighborhood': 'San Chaopho Suea',
#     'city': 'พระนคร',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['Phraeng Phuthon Rd',
#      'พระนคร',
#      'กรุงเทพมหานคร 10200',
#      'ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d1dd931735',
#      'name': 'Soup Place',
#      'pluralName': 'Soup Places',
#      'shortName': 'Soup',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/soup_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4e71841945dd2c5c1a3e3665-21'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c74ed938d70b713d833d4ad',
#    'name': 'ร้านน้อง ท่าพระจันทร์',
#    'location': {'address': 'Phra Chan Pier',
#     'lat': 13.756455805279812,
#     'lng': 100.48924032102019,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.756455805279812,
#       'lng': 100.48924032102019}],
#     'distance': 468,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'city': 'พระบรมมหาราชวัง',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['Phra Chan Pier',
#      'พระบรมมหาราชวัง',
#      'กรุงเทพมหานคร 10200',
#      'ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d10d951735',
#      'name': 'Record Shop',
#      'pluralName': 'Record Shops',
#      'shortName': 'Record Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/record_shop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c74ed938d70b713d833d4ad-22'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c3965ed2c8020a184b98c00',
#    'name': 'อาคุงเต้าฮวยโบราณ',
#    'location': {'address': 'Tha Chang',
#     'crossStreet': 'Na Phralan Rd.',
#     'lat': 13.752773,
#     'lng': 100.489456,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.752773,
#       'lng': 100.489456}],
#     'distance': 428,
#     'postalCode': '10200',
#     'cc': 'TH',
#     'city': 'พระบรมมหาราชวัง',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['Tha Chang (Na Phralan Rd.)',
#      'พระบรมมหาราชวัง',
#      'กรุงเทพมหานคร 10200',
#      'ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d1d0941735',
#      'name': 'Dessert Shop',
#      'pluralName': 'Dessert Shops',
#      'shortName': 'Desserts',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c3965ed2c8020a184b98c00-23'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4d2e7d96ad3a8cfad1e494bd',
#    'name': 'ศิริโภชนา',
#    'location': {'address': 'ตรงข้ามสำนักงานทนายคำนวน',
#     'crossStreet': 'ถนนบุญศิริ',
#     'lat': 13.754559748264908,
#     'lng': 100.49717140606322,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.754559748264908,
#       'lng': 100.49717140606322}],
#     'distance': 446,
#     'cc': 'TH',
#     'neighborhood': 'San Chaopho Suea',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['ตรงข้ามสำนักงานทนายคำนวน (ถนนบุญศิริ)',
#      'กรุงเทพมหานคร',
#      'ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d1d1941735',
#      'name': 'Noodle House',
#      'pluralName': 'Noodle Houses',
#      'shortName': 'Noodles',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4d2e7d96ad3a8cfad1e494bd-24'}]

# %%
bangkok_distinct_url = 'https://en.wikipedia.org/wiki/List_of_districts_of_Bangkok'
r = requests.get(bangkok_distinct_url)
df_list = pd.read_html(r.text)
df = df_list[0]
df.head()
# Out:
#   District(Khet)  MapNr  Post-code       Thai  Popu-lation  \
# 0       Bang Bon     50      10150     บางบอน       105161
# 1      Bang Kapi      6      10240    บางกะปิ       148465
# 2      Bang Khae     40      10160      บางแค       191781
# 3      Bang Khen      5      10220     บางเขน       189539
# 4  Bang Kho Laem     31      10120  บางคอแหลม        94956
#
#    No. ofSubdis-trictsKhwaeng   Latitude   Longitude
# 0                           4  13.659200  100.399100
# 1                           2  13.765833  100.647778
# 2                           4  13.696111  100.409444
# 3                           2  13.873889  100.596389
# 4                           3  13.693333  100.502500

# %%
df = df.rename(columns={"District(Khet)": "District", "Post-code": "Postcode", "Popu-lation": "Population", "No. ofSubdis-trictsKhwaeng": "No. of Subdistricts"})
df.head()
# Out:
#         District  MapNr  Postcode       Thai  Population  No. of Subdistricts  \
# 0       Bang Bon     50     10150     บางบอน      105161                    4
# 1      Bang Kapi      6     10240    บางกะปิ      148465                    2
# 2      Bang Khae     40     10160      บางแค      191781                    4
# 3      Bang Khen      5     10220     บางเขน      189539                    2
# 4  Bang Kho Laem     31     10120  บางคอแหลม       94956                    3
#
#     Latitude   Longitude
# 0  13.659200  100.399100
# 1  13.765833  100.647778
# 2  13.696111  100.409444
# 3  13.873889  100.596389
# 4  13.693333  100.502500

# %%
df.drop(['MapNr'], axis=1, inplace=True)

# %%
df.head()
# Out:
#         District  Postcode       Thai  Population  No. of Subdistricts  \
# 0       Bang Bon     10150     บางบอน      105161                    4
# 1      Bang Kapi     10240    บางกะปิ      148465                    2
# 2      Bang Khae     10160      บางแค      191781                    4
# 3      Bang Khen     10220     บางเขน      189539                    2
# 4  Bang Kho Laem     10120  บางคอแหลม       94956                    3
#
#     Latitude   Longitude
# 0  13.659200  100.399100
# 1  13.765833  100.647778
# 2  13.696111  100.409444
# 3  13.873889  100.596389
# 4  13.693333  100.502500

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, district in zip(df['Latitude'], df['Longitude'], df['District']):
    label = '{}'.format(district)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_eeb6f42b7dc24e038b0469a7cf76aef1%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_eeb6f42b7dc24e038b0469a7cf76aef1%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_eeb6f42b7dc24e038b0469a7cf76aef1%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_eeb6f42b7dc24e038b0469a7cf76aef1%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B13.7544238%2C100.4930399%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %%
bangkok_distinct_url = 'https://en.wikipedia.org/wiki/Khwaeng'
r = requests.get(bangkok_distinct_url)
df_list = pd.read_html(r.text)
df_sub_distincts = df_list[0]
df_sub_distincts.head()
# Out:
#   District (Khet)                                           \
#             Notes Unnamed: 1_level_1    Unnamed: 2_level_1
# 0            Code               Name  Name (Thai Alphabet)
# 1              01        Phra Nakhon                พระนคร
# 2              01        Phra Nakhon                พระนคร
# 3              01        Phra Nakhon                พระนคร
# 4              01        Phra Nakhon                พระนคร
#
#   Subdistrict (Khwaeng)                                                    \
#      Unnamed: 3_level_1          Unnamed: 4_level_1    Unnamed: 5_level_1
# 0                  Code                        Name  Name (Thai Alphabet)
# 1                    01  Phra Borom Maha Ratchawang       พระบรมมหาราชวัง
# 2                    02         Wang Burapha Phirom        วังบูรพาภิรมย์
# 3                    03            Wat Ratchabophit            วัดราชบพิธ
# 4                    04                  Samran Rat           สำราญราษฎร์
#
#                Notes
#   Unnamed: 6_level_1
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
df_sub_distincts.columns
# Out:
# MultiIndex([(      'District (Khet)',              'Notes'),
#             (      'District (Khet)', 'Unnamed: 1_level_1'),
#             (      'District (Khet)', 'Unnamed: 2_level_1'),
#             ('Subdistrict (Khwaeng)', 'Unnamed: 3_level_1'),
#             ('Subdistrict (Khwaeng)', 'Unnamed: 4_level_1'),
#             ('Subdistrict (Khwaeng)', 'Unnamed: 5_level_1'),
#             (                'Notes', 'Unnamed: 6_level_1')],
#            )

# %%
df_sub_distincts.columns = ['_'.join(col) for col in df_sub_distincts.columns.values]

# %%
df_sub_distincts.head()
# Out:
#   District (Khet)_Notes District (Khet)_Unnamed: 1_level_1  \
# 0                  Code                               Name
# 1                    01                        Phra Nakhon
# 2                    01                        Phra Nakhon
# 3                    01                        Phra Nakhon
# 4                    01                        Phra Nakhon
#
#   District (Khet)_Unnamed: 2_level_1 Subdistrict (Khwaeng)_Unnamed: 3_level_1  \
# 0               Name (Thai Alphabet)                                     Code
# 1                             พระนคร                                       01
# 2                             พระนคร                                       02
# 3                             พระนคร                                       03
# 4                             พระนคร                                       04
#
#   Subdistrict (Khwaeng)_Unnamed: 4_level_1  \
# 0                                     Name
# 1               Phra Borom Maha Ratchawang
# 2                      Wang Burapha Phirom
# 3                         Wat Ratchabophit
# 4                               Samran Rat
#
#   Subdistrict (Khwaeng)_Unnamed: 5_level_1 Notes_Unnamed: 6_level_1
# 0                     Name (Thai Alphabet)                      NaN
# 1                          พระบรมมหาราชวัง                      NaN
# 2                           วังบูรพาภิรมย์                      NaN
# 3                               วัดราชบพิธ                      NaN
# 4                              สำราญราษฎร์                      NaN

# %%
df_sub_distincts.columns
# Out:
# Index(['District (Khet)_Notes', 'District (Khet)_Unnamed: 1_level_1',
#        'District (Khet)_Unnamed: 2_level_1',
#        'Subdistrict (Khwaeng)_Unnamed: 3_level_1',
#        'Subdistrict (Khwaeng)_Unnamed: 4_level_1',
#        'Subdistrict (Khwaeng)_Unnamed: 5_level_1', 'Notes_Unnamed: 6_level_1'],
#       dtype='object')

# %%
df_sub_distincts.drop(['Notes_Unnamed: 6_level_1', 'District (Khet)_Unnamed: 2_level_1', 'Subdistrict (Khwaeng)_Unnamed: 5_level_1'], axis=1, inplace=True)

# %%
df_sub_distincts = df_sub_distincts.rename(columns={"District (Khet)_Notes": "District Code",
                                                    "District (Khet)_Unnamed: 1_level_1": "District Name",
                                                    "Subdistrict (Khwaeng)_Unnamed: 3_level_1": "Subdistrict Code",
                                                    "Subdistrict (Khwaeng)_Unnamed: 4_level_1": "Subdistrict Name"
                                                   })

# %%
df_sub_distincts
# Out:
#     District Code District Name Subdistrict Code            Subdistrict Name
# 0            Code          Name             Code                        Name
# 1              01   Phra Nakhon               01  Phra Borom Maha Ratchawang
# 2              01   Phra Nakhon               02         Wang Burapha Phirom
# 3              01   Phra Nakhon               03            Wat Ratchabophit
# 4              01   Phra Nakhon               04                  Samran Rat
# ..            ...           ...              ...                         ...
# 176            49    Thung Khru               02                  Thung Khru
# 177            50      Bang Bon               02               Bang Bon Nuea
# 178            50      Bang Bon               03                Bang Bon Tai
# 179            50      Bang Bon               04           Khlong Bang Phran
# 180            50      Bang Bon               05             Khlong Bang Bon
#
# [181 rows x 4 columns]

# %%
df_sub_distincts.drop(axis=0, index=0, inplace=True)

# %%
df_sub_distincts
# Out:
#     District Code District Name Subdistrict Code            Subdistrict Name
# 1              01   Phra Nakhon               01  Phra Borom Maha Ratchawang
# 2              01   Phra Nakhon               02         Wang Burapha Phirom
# 3              01   Phra Nakhon               03            Wat Ratchabophit
# 4              01   Phra Nakhon               04                  Samran Rat
# 5              01   Phra Nakhon               05            San Chaopho Suea
# ..            ...           ...              ...                         ...
# 176            49    Thung Khru               02                  Thung Khru
# 177            50      Bang Bon               02               Bang Bon Nuea
# 178            50      Bang Bon               03                Bang Bon Tai
# 179            50      Bang Bon               04           Khlong Bang Phran
# 180            50      Bang Bon               05             Khlong Bang Bon
#
# [180 rows x 4 columns]

# %%
LIMIT = 100
radius = 500
lat = 13.659200
lon = 100.399100

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    lat, 
    lon, 
    radius, 
    LIMIT)

# %%
results_bangbon = requests.get(url).json()["response"]['groups'][0]['items']
results_bangbon
# Out:
# [{'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4e880a81f790e992e01d7284',
#    'name': 'ขาหมูบางหว้า',
#    'location': {'address': 'Ekkachai 108',
#     'lat': 13.657136,
#     'lng': 100.39523,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.657136,
#       'lng': 100.39523}],
#     'distance': 477,
#     'postalCode': '10150',
#     'cc': 'TH',
#     'neighborhood': 'Bang Bon',
#     'city': 'บางบอน',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['Ekkachai 108',
#      'บางบอน',
#      'กรุงเทพมหานคร 10150',
#      'ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d149941735',
#      'name': 'Thai Restaurant',
#      'pluralName': 'Thai Restaurants',
#      'shortName': 'Thai',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4e880a81f790e992e01d7284-0'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5218ae3411d247f3bb76befc',
#    'name': 'Irashaimase Japanese Restaurant',
#    'location': {'lat': 13.658358060432263,
#     'lng': 100.4014034321724,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.658358060432263,
#       'lng': 100.4014034321724}],
#     'distance': 266,
#     'cc': 'TH',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d111941735',
#      'name': 'Japanese Restaurant',
#      'pluralName': 'Japanese Restaurants',
#      'shortName': 'Japanese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5218ae3411d247f3bb76befc-1'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c12e245a9c220a181e2549d',
#    'name': 'Lotus Express (โลตัส เอ็กซ์เพรส)',
#    'location': {'address': 'บางบอน',
#     'crossStreet': 'เอกชัย',
#     'lat': 13.65783911965964,
#     'lng': 100.39724347536719,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.65783911965964,
#       'lng': 100.39724347536719}],
#     'distance': 251,
#     'cc': 'TH',
#     'neighborhood': 'Bang Bon',
#     'city': 'บางบอน',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['บางบอน (เอกชัย)',
#      'บางบอน',
#      'กรุงเทพมหานคร',
#      'ประเทศไทย']},
#    'categories': [{'id': '4d954b0ea243a5684a65b473',
#      'name': 'Convenience Store',
#      'pluralName': 'Convenience Stores',
#      'shortName': 'Convenience Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c12e245a9c220a181e2549d-2'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4d99a97cdaec224b7fba633e',
#    'name': 'Tesco Lotus Express thanon ekkachai bangbon',
#    'location': {'lat': 13.657758,
#     'lng': 100.397366,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.657758,
#       'lng': 100.397366}],
#     'distance': 246,
#     'cc': 'TH',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d1fd941735',
#      'name': 'Shopping Mall',
#      'pluralName': 'Shopping Malls',
#      'shortName': 'Mall',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4d99a97cdaec224b7fba633e-3'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4d63aa471a83f04d75ae752b',
#    'name': 'Lotus Express Bongbon',
#    'location': {'address': 'ถนนเอกชัย',
#     'lat': 13.657629926070491,
#     'lng': 100.3973252372851,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.657629926070491,
#       'lng': 100.3973252372851}],
#     'distance': 259,
#     'cc': 'TH',
#     'city': 'บางบอน',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['ถนนเอกชัย', 'บางบอน', 'กรุงเทพมหานคร', 'ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d118951735',
#      'name': 'Grocery Store',
#      'pluralName': 'Grocery Stores',
#      'shortName': 'Grocery Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4d63aa471a83f04d75ae752b-4'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4e6d908818380b4aac0cde6e',
#    'name': 'ก๋วยเตี๋ยวปลา แม่ช้อนทอง',
#    'location': {'lat': 13.657938,
#     'lng': 100.396723,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.657938,
#       'lng': 100.396723}],
#     'distance': 292,
#     'cc': 'TH',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d1d1941735',
#      'name': 'Noodle House',
#      'pluralName': 'Noodle Houses',
#      'shortName': 'Noodles',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4e6d908818380b4aac0cde6e-5'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4d78b8db71a68cfaef9b0986',
#    'name': 'Sticker I Do',
#    'location': {'address': 'เอกชัย',
#     'crossStreet': 'เอกชัย',
#     'lat': 13.657734487389293,
#     'lng': 100.39575648969992,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 13.657734487389293,
#       'lng': 100.39575648969992}],
#     'distance': 396,
#     'cc': 'TH',
#     'city': 'บางบอน',
#     'state': 'กรุงเทพมหานคร',
#     'country': 'ประเทศไทย',
#     'formattedAddress': ['เอกชัย (เอกชัย)',
#      'บางบอน',
#      'กรุงเทพมหานคร',
#      'ประเทศไทย']},
#    'categories': [{'id': '4bf58dd8d48988d124951735',
#      'name': 'Automotive Shop',
#      'pluralName': 'Automotive Shops',
#      'shortName': 'Automotive',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4d78b8db71a68cfaef9b0986-6'}]

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
df = getNearbyVenues(names=df['District'], 
                    latitudes=df['Latitude'], 
                    longitudes=df['Longitude'])

# %%
df.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0     Bang Bon                13.6592                100.3991
# 1     Bang Bon                13.6592                100.3991
# 2     Bang Bon                13.6592                100.3991
# 3     Bang Bon                13.6592                100.3991
# 4     Bang Bon                13.6592                100.3991
#
#                                          Venue  Venue Latitude  \
# 0                                 ขาหมูบางหว้า       13.657136
# 1              Irashaimase Japanese Restaurant       13.658358
# 2             Lotus Express (โลตัส เอ็กซ์เพรส)       13.657839
# 3  Tesco Lotus Express thanon ekkachai bangbon       13.657758
# 4                        Lotus Express Bongbon       13.657630
#
#    Venue Longitude       Venue Category
# 0       100.395230      Thai Restaurant
# 1       100.401403  Japanese Restaurant
# 2       100.397243    Convenience Store
# 3       100.397366        Shopping Mall
# 4       100.397325        Grocery Store

# %%
df
# Out:
#      Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0        Bang Bon              13.659200              100.399100
# 1        Bang Bon              13.659200              100.399100
# 2        Bang Bon              13.659200              100.399100
# 3        Bang Bon              13.659200              100.399100
# 4        Bang Bon              13.659200              100.399100
# ...           ...                    ...                     ...
# 1157     Yan Nawa              13.696944              100.543056
# 1158     Yan Nawa              13.696944              100.543056
# 1159     Yan Nawa              13.696944              100.543056
# 1160     Yan Nawa              13.696944              100.543056
# 1161     Yan Nawa              13.696944              100.543056
#
#                                             Venue  Venue Latitude  \
# 0                                    ขาหมูบางหว้า       13.657136
# 1                 Irashaimase Japanese Restaurant       13.658358
# 2                Lotus Express (โลตัส เอ็กซ์เพรส)       13.657839
# 3     Tesco Lotus Express thanon ekkachai bangbon       13.657758
# 4                           Lotus Express Bongbon       13.657630
# ...                                           ...             ...
# 1157                                Lavita Coffee       13.698132
# 1158                                   Food Court       13.696740
# 1159                                KFC (เคเอฟซี)       13.700420
# 1160                Rumruay Pochana (ร่ำรวยโภชนา)       13.699501
# 1161                          Acer Service Center       13.700052
#
#       Venue Longitude        Venue Category
# 0          100.395230       Thai Restaurant
# 1          100.401403   Japanese Restaurant
# 2          100.397243     Convenience Store
# 3          100.397366         Shopping Mall
# 4          100.397325         Grocery Store
# ...               ...                   ...
# 1157       100.540867           Coffee Shop
# 1158       100.541071            Food Court
# 1159       100.540930  Fast Food Restaurant
# 1160       100.541553    Chinese Restaurant
# 1161       100.545886     Electronics Store
#
# [1162 rows x 7 columns]

# %%
# df.to_csv(index=False, encoding="utf-8")

# %%
compression_opts = dict(method='zip',
                        archive_name='bkk.csv')  
df.to_csv('bkk.zip', index=False,
          compression=compression_opts, encoding='utf-8-sig')

# %%
siam = (13.7438306,100.5151677)

# %%
siam
# Out:
# (13.7438306, 100.5151677)

# %%
df.groupby(['Neighborhood'])['Venue'].count()
# Out:
# Neighborhood
# Bang Bon                 7
# Bang Kapi               19
# Bang Khae               14
# Bang Khen               14
# Bang Kho Laem           17
# Bang Khun Thian         44
# Bang Na                  7
# Bang Phlat              11
# Bang Rak                26
# Bang Sue                14
# Bangkok Noi             25
# Bangkok Yai             20
# Bueng Kum                6
# Chatuchak               25
# Chom Thong               5
# Din Daeng               10
# Don Mueang              10
# Dusit                   18
# Huai Khwang             23
# Khan Na Yao             47
# Khlong Sam Wa            8
# Khlong San              52
# Khlong Toei              8
# Lak Si                  28
# Lat Krabang              8
# Lat Phrao               25
# Min Buri                 7
# Nong Chok                8
# Nong Khaem               6
# Pathum Wan              82
# Phasi Charoen           45
# Phaya Thai              89
# Phra Khanong            25
# Phra Nakhon             39
# Pom Prap Sattru Phai    38
# Prawet                   8
# Rat Burana               9
# Ratchathewi             42
# Sai Mai                  8
# Samphanthawong          31
# Saphan Sung              5
# Sathon                  40
# Suan Luang              37
# Taling Chan              5
# Thawi Watthana          14
# Thon Buri               12
# Thung Khru              18
# Wang Thonglang          32
# Watthana                43
# Yan Nawa                28
# Name: Venue, dtype: int64

# %%
df.groupby(['Venue Category'])['Venue Category'].count().sort_values(ascending=False)
# Out:
# Venue Category
# Noodle House         126
# Convenience Store     80
# Coffee Shop           79
# Thai Restaurant       74
# Café                  53
#                     ...
# Pastry Shop            1
# Gaming Cafe            1
# Garden                 1
# Garden Center          1
# Women's Store          1
# Name: Venue Category, Length: 164, dtype: int64

# %%
df.loc[df['Venue Category']=='Thai Restaurant']
# Out:
#         Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0           Bang Bon              13.659200              100.399100
# 25         Bang Kapi              13.765833              100.647778
# 51         Bang Khen              13.873889              100.596389
# 55     Bang Kho Laem              13.693333              100.502500
# 56     Bang Kho Laem              13.693333              100.502500
# ...              ...                    ...                     ...
# 1085  Wang Thonglang              13.786400              100.608700
# 1086  Wang Thonglang              13.786400              100.608700
# 1128        Watthana              13.742222              100.585833
# 1141        Yan Nawa              13.696944              100.543056
# 1142        Yan Nawa              13.696944              100.543056
#
#                                     Venue  Venue Latitude  Venue Longitude  \
# 0                            ขาหมูบางหว้า       13.657136       100.395230
# 25                             ครัว ณ ราม       13.763695       100.650798
# 51    Ban Suan Klang Soi (บ้านสวนกลางซอย)       13.874157       100.600090
# 55        Baan Klang Krung (บ้านกลางกรุง)       13.690974       100.503151
# 56                    ห้องอาหารจันทร์เพ็ญ       13.692355       100.504234
# ...                                   ...             ...              ...
# 1085                       Tanu's Kitchen       13.789265       100.608255
# 1086                             เชียงคาน       13.789514       100.608936
# 1128         Mantana Cuisine (ครัวมัณฑนา)       13.743758       100.588570
# 1141                  Ruentong (เรือนทอง)       13.695640       100.546152
# 1142                       Seefah (สีฟ้า)       13.696860       100.540223
#
#        Venue Category
# 0     Thai Restaurant
# 25    Thai Restaurant
# 51    Thai Restaurant
# 55    Thai Restaurant
# 56    Thai Restaurant
# ...               ...
# 1085  Thai Restaurant
# 1086  Thai Restaurant
# 1128  Thai Restaurant
# 1141  Thai Restaurant
# 1142  Thai Restaurant
#
# [74 rows x 7 columns]

# %%
df.loc[df['Venue Category']=='Thai Restaurant'].groupby(['Neighborhood'])['Venue'].count()
# Out:
# Neighborhood
# Bang Bon                1
# Bang Kapi               1
# Bang Khen               1
# Bang Kho Laem           3
# Bang Khun Thian         3
# Bang Phlat              1
# Bang Rak                2
# Bang Sue                3
# Bangkok Noi             1
# Bangkok Yai             1
# Chatuchak               3
# Chom Thong              1
# Din Daeng               1
# Don Mueang              2
# Huai Khwang             1
# Khan Na Yao             3
# Khlong Sam Wa           1
# Khlong San              3
# Lak Si                  2
# Lat Krabang             2
# Lat Phrao               1
# Min Buri                1
# Nong Chok               1
# Pathum Wan              5
# Phaya Thai              9
# Phra Nakhon             3
# Pom Prap Sattru Phai    1
# Rat Burana              3
# Ratchathewi             1
# Sai Mai                 1
# Samphanthawong          1
# Saphan Sung             1
# Sathon                  2
# Suan Luang              2
# Thawi Watthana          1
# Wang Thonglang          2
# Watthana                1
# Yan Nawa                2
# Name: Venue, dtype: int64

# %%
df.loc[df['Venue Category']=='Bubble Tea Shop']
# Out:
#      Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 735  Phra Khanong              13.702222              100.601667
#
#                  Venue  Venue Latitude  Venue Longitude   Venue Category
# 735  KOI Thé (โคอิเตะ)       13.705526       100.601299  Bubble Tea Shop

# %%
x = df.groupby(['Venue Category'])['Venue Category'].count().sort_values(ascending=False)

# %%
x.keys()
# Out:
# Index(['Noodle House', 'Convenience Store', 'Coffee Shop', 'Thai Restaurant',
#        'Café', 'Asian Restaurant', 'Japanese Restaurant', 'Chinese Restaurant',
#        'Hotel', 'Dessert Shop',
#        ...
#        'Frozen Yogurt Shop', 'Photography Studio', 'Organic Grocery',
#        'Pharmacy', 'Pedestrian Plaza', 'Pastry Shop', 'Gaming Cafe', 'Garden',
#        'Garden Center', 'Women's Store'],
#       dtype='object', name='Venue Category', length=164)

# %%
x['American Restaurant']
# Out:
# 2

# %%
y = []

for k in x.keys():
    y.append({'Venue Category': k, 'Count': x[k]})
    
y
# Out:
# [{'Venue Category': 'Noodle House', 'Count': 126},
#  {'Venue Category': 'Convenience Store', 'Count': 80},
#  {'Venue Category': 'Coffee Shop', 'Count': 79},
#  {'Venue Category': 'Thai Restaurant', 'Count': 74},
#  {'Venue Category': 'Café', 'Count': 53},
#  {'Venue Category': 'Asian Restaurant', 'Count': 45},
#  {'Venue Category': 'Japanese Restaurant', 'Count': 33},
#  {'Venue Category': 'Chinese Restaurant', 'Count': 32},
#  {'Venue Category': 'Hotel', 'Count': 29},
#  {'Venue Category': 'Dessert Shop', 'Count': 27},
#  {'Venue Category': 'Som Tum Restaurant', 'Count': 22},
#  {'Venue Category': 'Hotpot Restaurant', 'Count': 21},
#  {'Venue Category': 'Fast Food Restaurant', 'Count': 20},
#  {'Venue Category': 'BBQ Joint', 'Count': 19},
#  {'Venue Category': 'Bakery', 'Count': 18},
#  {'Venue Category': 'Seafood Restaurant', 'Count': 16},
#  {'Venue Category': 'Steakhouse', 'Count': 16},
#  {'Venue Category': 'Shopping Mall', 'Count': 16},
#  {'Venue Category': 'Bar', 'Count': 13},
#  {'Venue Category': 'Ice Cream Shop', 'Count': 12},
#  {'Venue Category': 'Restaurant', 'Count': 11},
#  {'Venue Category': 'Gym / Fitness Center', 'Count': 11},
#  {'Venue Category': 'Massage Studio', 'Count': 11},
#  {'Venue Category': 'Park', 'Count': 10},
#  {'Venue Category': 'Flea Market', 'Count': 10},
#  {'Venue Category': 'Hostel', 'Count': 10},
#  {'Venue Category': 'Food Court', 'Count': 10},
#  {'Venue Category': 'Shabu-Shabu Restaurant', 'Count': 9},
#  {'Venue Category': 'Sushi Restaurant', 'Count': 9},
#  {'Venue Category': 'Pizza Place', 'Count': 8},
#  {'Venue Category': 'Italian Restaurant', 'Count': 8},
#  {'Venue Category': 'Supermarket', 'Count': 8},
#  {'Venue Category': 'Bookstore', 'Count': 8},
#  {'Venue Category': 'Clothing Store', 'Count': 7},
#  {'Venue Category': 'Dim Sum Restaurant', 'Count': 7},
#  {'Venue Category': 'Art Gallery', 'Count': 7},
#  {'Venue Category': 'Train Station', 'Count': 7},
#  {'Venue Category': 'Department Store', 'Count': 7},
#  {'Venue Category': 'Farmers Market', 'Count': 6},
#  {'Venue Category': 'Cocktail Bar', 'Count': 6},
#  {'Venue Category': 'Buffet', 'Count': 6},
#  {'Venue Category': 'Ramen Restaurant', 'Count': 6},
#  {'Venue Category': 'Market', 'Count': 6},
#  {'Venue Category': 'Hotel Bar', 'Count': 6},
#  {'Venue Category': 'Historic Site', 'Count': 5},
#  {'Venue Category': 'Vietnamese Restaurant', 'Count': 5},
#  {'Venue Category': 'Korean Restaurant', 'Count': 5},
#  {'Venue Category': 'Spa', 'Count': 5},
#  {'Venue Category': 'Badminton Court', 'Count': 4},
#  {'Venue Category': 'Multiplex', 'Count': 4},
#  {'Venue Category': 'Museum', 'Count': 4},
#  {'Venue Category': 'Beer Bar', 'Count': 4},
#  {'Venue Category': 'Halal Restaurant', 'Count': 4},
#  {'Venue Category': 'Food Truck', 'Count': 4},
#  {'Venue Category': 'Tea Room', 'Count': 4},
#  {'Venue Category': 'Soup Place', 'Count': 4},
#  {'Venue Category': 'Cosmetics Shop', 'Count': 4},
#  {'Venue Category': 'Stadium', 'Count': 4},
#  {'Venue Category': 'Breakfast Spot', 'Count': 4},
#  {'Venue Category': 'Music Venue', 'Count': 3},
#  {'Venue Category': 'Intersection', 'Count': 3},
#  {'Venue Category': 'Canal', 'Count': 3},
#  {'Venue Category': 'Bus Stop', 'Count': 3},
#  {'Venue Category': 'Pub', 'Count': 3},
#  {'Venue Category': 'Burger Joint', 'Count': 3},
#  {'Venue Category': 'Gift Shop', 'Count': 3},
#  {'Venue Category': 'Diner', 'Count': 3},
#  {'Venue Category': 'Electronics Store', 'Count': 3},
#  {'Venue Category': 'Fried Chicken Joint', 'Count': 3},
#  {'Venue Category': 'Sake Bar', 'Count': 2},
#  {'Venue Category': 'Other Nightlife', 'Count': 2},
#  {'Venue Category': 'Pool', 'Count': 2},
#  {'Venue Category': 'Jazz Club', 'Count': 2},
#  {'Venue Category': 'Sporting Goods Shop', 'Count': 2},
#  {'Venue Category': 'Theater', 'Count': 2},
#  {'Venue Category': 'Wings Joint', 'Count': 2},
#  {'Venue Category': 'Lounge', 'Count': 2},
#  {'Venue Category': 'Sports Club', 'Count': 2},
#  {'Venue Category': 'Playground', 'Count': 2},
#  {'Venue Category': 'Tour Provider', 'Count': 2},
#  {'Venue Category': 'Vegetarian / Vegan Restaurant', 'Count': 2},
#  {'Venue Category': 'Soccer Field', 'Count': 2},
#  {'Venue Category': 'Mobile Phone Shop', 'Count': 2},
#  {'Venue Category': 'Other Repair Shop', 'Count': 2},
#  {'Venue Category': 'Snack Place', 'Count': 2},
#  {'Venue Category': 'American Restaurant', 'Count': 2},
#  {'Venue Category': 'Japanese Curry Restaurant', 'Count': 2},
#  {'Venue Category': 'Donburi Restaurant', 'Count': 2},
#  {'Venue Category': 'Building', 'Count': 2},
#  {'Venue Category': 'Furniture / Home Store', 'Count': 2},
#  {'Venue Category': 'Food & Drink Shop', 'Count': 2},
#  {'Venue Category': 'Big Box Store', 'Count': 2},
#  {'Venue Category': 'Bed & Breakfast', 'Count': 2},
#  {'Venue Category': 'Grocery Store', 'Count': 2},
#  {'Venue Category': 'Health & Beauty Service', 'Count': 2},
#  {'Venue Category': 'Auto Garage', 'Count': 2},
#  {'Venue Category': 'Comfort Food Restaurant', 'Count': 2},
#  {'Venue Category': 'Donut Shop', 'Count': 1},
#  {'Venue Category': 'Shoe Store', 'Count': 1},
#  {'Venue Category': 'College Quad', 'Count': 1},
#  {'Venue Category': 'Satay Restaurant', 'Count': 1},
#  {'Venue Category': 'Dog Run', 'Count': 1},
#  {'Venue Category': 'Salad Place', 'Count': 1},
#  {'Venue Category': 'Skating Rink', 'Count': 1},
#  {'Venue Category': 'Dive Shop', 'Count': 1},
#  {'Venue Category': 'Discount Store', 'Count': 1},
#  {'Venue Category': 'Dumpling Restaurant', 'Count': 1},
#  {'Venue Category': 'Soccer Stadium', 'Count': 1},
#  {'Venue Category': 'Coworking Space', 'Count': 1},
#  {'Venue Category': 'Bus Line', 'Count': 1},
#  {'Venue Category': 'Speakeasy', 'Count': 1},
#  {'Venue Category': 'Tonkatsu Restaurant', 'Count': 1},
#  {'Venue Category': 'Arts & Entertainment', 'Count': 1},
#  {'Venue Category': 'Wine Bar', 'Count': 1},
#  {'Venue Category': 'Veterinarian', 'Count': 1},
#  {'Venue Category': 'Automotive Shop', 'Count': 1},
#  {'Venue Category': 'Udon Restaurant', 'Count': 1},
#  {'Venue Category': 'Toy / Game Store', 'Count': 1},
#  {'Venue Category': 'Bike Rental / Bike Share', 'Count': 1},
#  {'Venue Category': 'Cantonese Restaurant', 'Count': 1},
#  {'Venue Category': 'Bistro', 'Count': 1},
#  {'Venue Category': 'Bowling Alley', 'Count': 1},
#  {'Venue Category': 'Brewery', 'Count': 1},
#  {'Venue Category': 'Bubble Tea Shop', 'Count': 1},
#  {'Venue Category': 'River', 'Count': 1},
#  {'Venue Category': 'Cafeteria', 'Count': 1},
#  {'Venue Category': 'Roof Deck', 'Count': 1},
#  {'Venue Category': 'Rest Area', 'Count': 1},
#  {'Venue Category': 'Duty-free Shop', 'Count': 1},
#  {'Venue Category': 'Antique Shop', 'Count': 1},
#  {'Venue Category': 'Nightclub', 'Count': 1},
#  {'Venue Category': 'Neighborhood', 'Count': 1},
#  {'Venue Category': 'German Restaurant', 'Count': 1},
#  {'Venue Category': 'Golf Driving Range', 'Count': 1},
#  {'Venue Category': 'Gourmet Shop', 'Count': 1},
#  {'Venue Category': 'Movie Theater', 'Count': 1},
#  {'Venue Category': 'Monument / Landmark', 'Count': 1},
#  {'Venue Category': 'Mexican Restaurant', 'Count': 1},
#  {'Venue Category': 'Mediterranean Restaurant', 'Count': 1},
#  {'Venue Category': 'Medical Center', 'Count': 1},
#  {'Venue Category': 'Gym', 'Count': 1},
#  {'Venue Category': 'History Museum', 'Count': 1},
#  {'Venue Category': 'Hotel Pool', 'Count': 1},
#  {'Venue Category': 'Karaoke Bar', 'Count': 1},
#  {'Venue Category': 'Juice Bar', 'Count': 1},
#  {'Venue Category': 'Gay Bar', 'Count': 1},
#  {'Venue Category': 'Office', 'Count': 1},
#  {'Venue Category': 'Optical Shop', 'Count': 1},
#  {'Venue Category': 'Pier', 'Count': 1},
#  {'Venue Category': 'Residential Building (Apartment / Condo)', 'Count': 1},
#  {'Venue Category': 'Recreation Center', 'Count': 1},
#  {'Venue Category': 'Recording Studio', 'Count': 1},
#  {'Venue Category': 'Floating Market', 'Count': 1},
#  {'Venue Category': 'Food', 'Count': 1},
#  {'Venue Category': 'Frozen Yogurt Shop', 'Count': 1},
#  {'Venue Category': 'Photography Studio', 'Count': 1},
#  {'Venue Category': 'Organic Grocery', 'Count': 1},
#  {'Venue Category': 'Pharmacy', 'Count': 1},
#  {'Venue Category': 'Pedestrian Plaza', 'Count': 1},
#  {'Venue Category': 'Pastry Shop', 'Count': 1},
#  {'Venue Category': 'Gaming Cafe', 'Count': 1},
#  {'Venue Category': 'Garden', 'Count': 1},
#  {'Venue Category': 'Garden Center', 'Count': 1},
#  {'Venue Category': "Women's Store", 'Count': 1}]

# %%
df2 = pd.DataFrame(y)
df2.head()
# Out:
#       Venue Category  Count
# 0       Noodle House    126
# 1  Convenience Store     80
# 2        Coffee Shop     79
# 3    Thai Restaurant     74
# 4               Café     53

# %%
x1 = pd.DataFrame(x)

# %%
x1
# Out:
#                    Venue Category
# Venue Category
# Noodle House                  126
# Convenience Store              80
# Coffee Shop                    79
# Thai Restaurant                74
# Café                           53
# ...                           ...
# Pastry Shop                     1
# Gaming Cafe                     1
# Garden                          1
# Garden Center                   1
# Women's Store                   1
#
# [164 rows x 1 columns]

# %%
compression_opts = dict(method='zip',
                        archive_name='bkk2.csv')  
df2.to_csv('bkk2.zip', index=False,
          compression=compression_opts, encoding='utf-8-sig')

# %%
# df.plot(
#     kind='scatter'
#     x=''
#     y=''
# )

# plt.title('')
# plt.xlabel('')
# plt.ylabel('')

# plt.show()

# %%
food_category = '4d4b7105d754a06374d81259'

# %%
restaurant_words = ['restaurant', 'food', 'noodle', 'diner', 'steakhouse', 'pizza', 'donut', 'salad']

# %%
def is_restaurant(categories, specific_filter=None):
    restaurant_words = ['restaurant', 'food', 'noodle', 'diner', 'steakhouse', 'pizza']
    restaurant = False
    specific = False
    for c in categories:
        category_name = c[0].lower()
        category_id = c[1]
        for r in restaurant_words:
            if r in category_name:
                restaurant = True
        if 'fast food' in category_name:
            restaurant = False
        if not(specific_filter is None) and (category_id in specific_filter):
            specific = True
            restaurant = True
    return restaurant, specific

# %%
def get_venues_near_location(lat, lon, category, client_id, client_secret, radius=500, limit=100):
    version = '20180724'
    url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&categoryId={}&radius={}&limit={}'.format(
        client_id, client_secret, version, lat, lon, category, radius, limit)
    try:
        results = requests.get(url).json()['response']['groups'][0]['items']
        venues = [(item['venue']['id'],
                   item['venue']['name'],
                   get_categories(item['venue']['categories']),
                   (item['venue']['location']['lat'], item['venue']['location']['lng']),
                   format_address(item['venue']['location']),
                   item['venue']['location']['distance']) for item in results]        
    except:
        venues = []
    return venues

# %%
a = df.loc[df['Venue Category']=='Thai Restaurant'].groupby(['Neighborhood'])['Venue'].count().sort_values(ascending=False)

# %%
b = []

for k in a.keys():
    b.append({'Distict': k, 'Count': a[k]})
    
b
# Out:
# [{'Distict': 'Phaya Thai', 'Count': 9},
#  {'Distict': 'Pathum Wan', 'Count': 5},
#  {'Distict': 'Khan Na Yao', 'Count': 3},
#  {'Distict': 'Bang Kho Laem', 'Count': 3},
#  {'Distict': 'Bang Khun Thian', 'Count': 3},
#  {'Distict': 'Bang Sue', 'Count': 3},
#  {'Distict': 'Rat Burana', 'Count': 3},
#  {'Distict': 'Phra Nakhon', 'Count': 3},
#  {'Distict': 'Chatuchak', 'Count': 3},
#  {'Distict': 'Khlong San', 'Count': 3},
#  {'Distict': 'Lat Krabang', 'Count': 2},
#  {'Distict': 'Wang Thonglang', 'Count': 2},
#  {'Distict': 'Suan Luang', 'Count': 2},
#  {'Distict': 'Sathon', 'Count': 2},
#  {'Distict': 'Lak Si', 'Count': 2},
#  {'Distict': 'Yan Nawa', 'Count': 2},
#  {'Distict': 'Don Mueang', 'Count': 2},
#  {'Distict': 'Bang Rak', 'Count': 2},
#  {'Distict': 'Khlong Sam Wa', 'Count': 1},
#  {'Distict': 'Ratchathewi', 'Count': 1},
#  {'Distict': 'Watthana', 'Count': 1},
#  {'Distict': 'Bang Khen', 'Count': 1},
#  {'Distict': 'Thawi Watthana', 'Count': 1},
#  {'Distict': 'Bang Phlat', 'Count': 1},
#  {'Distict': 'Saphan Sung', 'Count': 1},
#  {'Distict': 'Samphanthawong', 'Count': 1},
#  {'Distict': 'Sai Mai', 'Count': 1},
#  {'Distict': 'Bangkok Noi', 'Count': 1},
#  {'Distict': 'Huai Khwang', 'Count': 1},
#  {'Distict': 'Pom Prap Sattru Phai', 'Count': 1},
#  {'Distict': 'Bangkok Yai', 'Count': 1},
#  {'Distict': 'Chom Thong', 'Count': 1},
#  {'Distict': 'Din Daeng', 'Count': 1},
#  {'Distict': 'Nong Chok', 'Count': 1},
#  {'Distict': 'Min Buri', 'Count': 1},
#  {'Distict': 'Lat Phrao', 'Count': 1},
#  {'Distict': 'Bang Kapi', 'Count': 1},
#  {'Distict': 'Bang Bon', 'Count': 1}]

# %%
df3 = pd.DataFrame(b)
df3
# Out:
#                  Distict  Count
# 0             Phaya Thai      9
# 1             Pathum Wan      5
# 2            Khan Na Yao      3
# 3          Bang Kho Laem      3
# 4        Bang Khun Thian      3
# 5               Bang Sue      3
# 6             Rat Burana      3
# 7            Phra Nakhon      3
# 8              Chatuchak      3
# 9             Khlong San      3
# 10           Lat Krabang      2
# 11        Wang Thonglang      2
# 12            Suan Luang      2
# 13                Sathon      2
# 14                Lak Si      2
# 15              Yan Nawa      2
# 16            Don Mueang      2
# 17              Bang Rak      2
# 18         Khlong Sam Wa      1
# 19           Ratchathewi      1
# 20              Watthana      1
# 21             Bang Khen      1
# 22        Thawi Watthana      1
# 23            Bang Phlat      1
# 24           Saphan Sung      1
# 25        Samphanthawong      1
# 26               Sai Mai      1
# 27           Bangkok Noi      1
# 28           Huai Khwang      1
# 29  Pom Prap Sattru Phai      1
# 30           Bangkok Yai      1
# 31            Chom Thong      1
# 32             Din Daeng      1
# 33             Nong Chok      1
# 34              Min Buri      1
# 35             Lat Phrao      1
# 36             Bang Kapi      1
# 37              Bang Bon      1

# %%
df3.plot(kind='bar', x='Distict', y='Count', rot=0)
plt.xticks(rotation=90)
plt.show()
