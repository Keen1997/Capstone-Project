# %% [markdown]
# <h1>Segmenting and Clustering Neighborhoods in Toronto</h1>

# %% [markdown]
# <h2>Import Libraby</h2>

# %%
import requests  

import pandas as pd 
from pandas.io.json import json_normalize

import numpy as np

from geopy.geocoders import Nominatim 
import geocoder 

import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans

import folium

# %% [markdown]
# <h2>Get Toronto Data</h2>

# %%
url= 'https://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&oldid=945633050'

# %%
r = requests.get(url)
df_list = pd.read_html(r.text)
df = df_list[0]
df
# Out:
#     Postcode           Borough          Neighbourhood
# 0        M1A      Not assigned           Not assigned
# 1        M2A      Not assigned           Not assigned
# 2        M3A        North York              Parkwoods
# 3        M4A        North York       Victoria Village
# 4        M5A  Downtown Toronto           Harbourfront
# ..       ...               ...                    ...
# 282      M8Z         Etobicoke              Mimico NW
# 283      M8Z         Etobicoke     The Queensway West
# 284      M8Z         Etobicoke  Royal York South West
# 285      M8Z         Etobicoke         South of Bloor
# 286      M9Z      Not assigned           Not assigned
#
# [287 rows x 3 columns]

# %%
df = df[df['Borough']!= 'Not assigned']
df = df[df['Neighbourhood']!= 'Not assigned']
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M6A        North York  Lawrence Heights
# 6      M6A        North York    Lawrence Manor

# %%
df.shape
# Out:
# (210, 3)

# %% [markdown]
# <h2>Get Coordinates Data and Merge</h2>

# %%
df_coordinates = pd.read_csv('Geospatial_Coordinates.csv')
df_coordinates.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df.rename({'Postcode': 'Postal Code', 'Neighbourhood': 'Neighborhood'}, axis=1, inplace=True)

# %%
df = pd.merge(df, df_coordinates, on='Postal Code')
df
# Out:
#     Postal Code           Borough              Neighborhood   Latitude  \
# 0           M3A        North York                 Parkwoods  43.753259
# 1           M4A        North York          Victoria Village  43.725882
# 2           M5A  Downtown Toronto              Harbourfront  43.654260
# 3           M6A        North York          Lawrence Heights  43.718518
# 4           M6A        North York            Lawrence Manor  43.718518
# ..          ...               ...                       ...        ...
# 205         M8Z         Etobicoke  Kingsway Park South West  43.628841
# 206         M8Z         Etobicoke                 Mimico NW  43.628841
# 207         M8Z         Etobicoke        The Queensway West  43.628841
# 208         M8Z         Etobicoke     Royal York South West  43.628841
# 209         M8Z         Etobicoke            South of Bloor  43.628841
#
#      Longitude
# 0   -79.329656
# 1   -79.315572
# 2   -79.360636
# 3   -79.464763
# 4   -79.464763
# ..         ...
# 205 -79.520999
# 206 -79.520999
# 207 -79.520999
# 208 -79.520999
# 209 -79.520999
#
# [210 rows x 5 columns]

# %%
df.groupby("Borough").count()
# Out:
#                   Postal Code  Neighborhood  Latitude  Longitude
# Borough
# Central Toronto            17            17        17         17
# Downtown Toronto           37            37        37         37
# East Toronto                7             7         7          7
# East York                   6             6         6          6
# Etobicoke                  45            45        45         45
# Mississauga                 1             1         1          1
# North York                 38            38        38         38
# Scarborough                37            37        37         37
# West Toronto               13            13        13         13
# York                        9             9         9          9

# %% [markdown]
# <h2>Show Map of Neighbourhood</h2>

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto City are 43.6534817, -79.3839347.

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, borough, Neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighborhood']):
    label = '{}, {}'.format(Neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_f64e174e77e2420fa383d4120b218b28%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f64e174e77e2420fa383d4120b218b28%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f64e174e77e2420fa383d4120b218b28%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_f64e174e77e2420fa383d4120b218b28%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.6534817%2C-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# <h2>Only Borough Contain Word 'Toronto'</h2>

# %%
df = df[df['Borough'].str.contains("Toronto")]
df
# Out:
#     Postal Code           Borough  \
# 2           M5A  Downtown Toronto
# 5           M7A  Downtown Toronto
# 12          M5B  Downtown Toronto
# 13          M5B  Downtown Toronto
# 26          M5C  Downtown Toronto
# ..          ...               ...
# 189         M4X  Downtown Toronto
# 190         M5X  Downtown Toronto
# 191         M5X  Downtown Toronto
# 195         M4Y  Downtown Toronto
# 196         M7Y      East Toronto
#
#                                           Neighborhood   Latitude  Longitude
# 2                                         Harbourfront  43.654260 -79.360636
# 5                                         Queen's Park  43.662301 -79.389494
# 12                                             Ryerson  43.657162 -79.378937
# 13                                     Garden District  43.657162 -79.378937
# 26                                      St. James Town  43.651494 -79.375418
# ..                                                 ...        ...        ...
# 189                                     St. James Town  43.667967 -79.367675
# 190                               First Canadian Place  43.648429 -79.382280
# 191                                   Underground city  43.648429 -79.382280
# 195                               Church and Wellesley  43.665860 -79.383160
# 196  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
#
# [74 rows x 5 columns]

# %%
df.groupby("Borough").count()
# Out:
#                   Postal Code  Neighborhood  Latitude  Longitude
# Borough
# Central Toronto            17            17        17         17
# Downtown Toronto           37            37        37         37
# East Toronto                7             7         7          7
# West Toronto               13            13        13         13

# %% [markdown]
# <h2>Show Map of Neighbourhood after Filter</h2>

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, borough, Neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighborhood']):
    label = '{}, {}'.format(Neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_1870263cb98e445982b4ca9d752d8b35%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1870263cb98e445982b4ca9d752d8b35%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_1870263cb98e445982b4ca9d752d8b35%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_1870263cb98e445982b4ca9d752d8b35%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.6534817%2C-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# <h2>Set API Config</h2>

# %%
CLIENT_ID = 'IRNDM0FF5HHW4I3AACXII3TW5ZOUJOUNK0QHJLFFSJ5ITPZE' # your Foursquare ID
CLIENT_SECRET = 'THW2UZ4OV0ISDLZW4V4OT5C0UWQQK10LZTJQ1QJKFTZ2KUZJ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: IRNDM0FF5HHW4I3AACXII3TW5ZOUJOUNK0QHJLFFSJ5ITPZE
# CLIENT_SECRET:THW2UZ4OV0ISDLZW4V4OT5C0UWQQK10LZTJQ1QJKFTZ2KUZJ

# %% [markdown]
# <h2>Get Downtown Toronto Venues</h2>

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
downtown_toronto_data = df[df['Borough'] == 'Downtown Toronto'].reset_index(drop=True)
downtown_toronto_data.head()
# Out:
#   Postal Code           Borough     Neighborhood   Latitude  Longitude
# 0         M5A  Downtown Toronto     Harbourfront  43.654260 -79.360636
# 1         M7A  Downtown Toronto     Queen's Park  43.662301 -79.389494
# 2         M5B  Downtown Toronto          Ryerson  43.657162 -79.378937
# 3         M5B  Downtown Toronto  Garden District  43.657162 -79.378937
# 4         M5C  Downtown Toronto   St. James Town  43.651494 -79.375418

# %%
downtown_toronto_venues = getNearbyVenues(names=downtown_toronto_data['Neighborhood'], 
                                          latitudes=downtown_toronto_data['Latitude'], 
                                          longitudes=downtown_toronto_data['Longitude'])

# %%
print(downtown_toronto_venues.shape)
downtown_toronto_venues.head()
# Out:
# (2290, 7)
#    Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Harbourfront               43.65426              -79.360636
# 1  Harbourfront               43.65426              -79.360636
# 2  Harbourfront               43.65426              -79.360636
# 3  Harbourfront               43.65426              -79.360636
# 4  Harbourfront               43.65426              -79.360636
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 0        Roselle Desserts       43.653447       -79.362017
# 1           Tandem Coffee       43.653559       -79.361809
# 2  Cooper Koo Family YMCA       43.653249       -79.358008
# 3     Body Blitz Spa East       43.654735       -79.359874
# 4          Impact Kitchen       43.656369       -79.356980
#
#         Venue Category
# 0               Bakery
# 1          Coffee Shop
# 2  Distribution Center
# 3                  Spa
# 4           Restaurant

# %%
downtown_toronto_venues.groupby('Neighborhood').count()
# Out:
#                                  Neighborhood Latitude  \
# Neighborhood
# Adelaide                                            94
# Bathurst Quay                                       14
# Berczy Park                                         60
# CN Tower                                            14
# Cabbagetown                                         45
# Central Bay Street                                  62
# Chinatown                                           61
# Christie                                            16
# Church and Wellesley                                77
# Commerce Court                                     100
# Design Exchange                                    100
# First Canadian Place                               100
# Garden District                                    100
# Grange Park                                         61
# Harbord                                             32
# Harbourfront                                        45
# Harbourfront East                                  100
# Harbourfront West                                   14
# Island airport                                      14
# Kensington Market                                   61
# King                                                94
# King and Spadina                                    14
# Queen's Park                                        30
# Railway Lands                                       14
# Richmond                                            94
# Rosedale                                             4
# Ryerson                                            100
# South Niagara                                       14
# St. James Town                                     126
# Stn A PO Boxes 25 The Esplanade                     98
# Toronto Dominion Centre                            100
# Toronto Islands                                    100
# Underground city                                   100
# Union Station                                      100
# University of Toronto                               32
# Victoria Hotel                                     100
#
#                                  Neighborhood Longitude  Venue  \
# Neighborhood
# Adelaide                                             94     94
# Bathurst Quay                                        14     14
# Berczy Park                                          60     60
# CN Tower                                             14     14
# Cabbagetown                                          45     45
# Central Bay Street                                   62     62
# Chinatown                                            61     61
# Christie                                             16     16
# Church and Wellesley                                 77     77
# Commerce Court                                      100    100
# Design Exchange                                     100    100
# First Canadian Place                                100    100
# Garden District                                     100    100
# Grange Park                                          61     61
# Harbord                                              32     32
# Harbourfront                                         45     45
# Harbourfront East                                   100    100
# Harbourfront West                                    14     14
# Island airport                                       14     14
# Kensington Market                                    61     61
# King                                                 94     94
# King and Spadina                                     14     14
# Queen's Park                                         30     30
# Railway Lands                                        14     14
# Richmond                                             94     94
# Rosedale                                              4      4
# Ryerson                                             100    100
# South Niagara                                        14     14
# St. James Town                                      126    126
# Stn A PO Boxes 25 The Esplanade                      98     98
# Toronto Dominion Centre                             100    100
# Toronto Islands                                     100    100
# Underground city                                    100    100
# Union Station                                       100    100
# University of Toronto                                32     32
# Victoria Hotel                                      100    100
#
#                                  Venue Latitude  Venue Longitude  \
# Neighborhood
# Adelaide                                     94               94
# Bathurst Quay                                14               14
# Berczy Park                                  60               60
# CN Tower                                     14               14
# Cabbagetown                                  45               45
# Central Bay Street                           62               62
# Chinatown                                    61               61
# Christie                                     16               16
# Church and Wellesley                         77               77
# Commerce Court                              100              100
# Design Exchange                             100              100
# First Canadian Place                        100              100
# Garden District                             100              100
# Grange Park                                  61               61
# Harbord                                      32               32
# Harbourfront                                 45               45
# Harbourfront East                           100              100
# Harbourfront West                            14               14
# Island airport                               14               14
# Kensington Market                            61               61
# King                                         94               94
# King and Spadina                             14               14
# Queen's Park                                 30               30
# Railway Lands                                14               14
# Richmond                                     94               94
# Rosedale                                      4                4
# Ryerson                                     100              100
# South Niagara                                14               14
# St. James Town                              126              126
# Stn A PO Boxes 25 The Esplanade              98               98
# Toronto Dominion Centre                     100              100
# Toronto Islands                             100              100
# Underground city                            100              100
# Union Station                               100              100
# University of Toronto                        32               32
# Victoria Hotel                              100              100
#
#                                  Venue Category
# Neighborhood
# Adelaide                                     94
# Bathurst Quay                                14
# Berczy Park                                  60
# CN Tower                                     14
# Cabbagetown                                  45
# Central Bay Street                           62
# Chinatown                                    61
# Christie                                     16
# Church and Wellesley                         77
# Commerce Court                              100
# Design Exchange                             100
# First Canadian Place                        100
# Garden District                             100
# Grange Park                                  61
# Harbord                                      32
# Harbourfront                                 45
# Harbourfront East                           100
# Harbourfront West                            14
# Island airport                               14
# Kensington Market                            61
# King                                         94
# King and Spadina                             14
# Queen's Park                                 30
# Railway Lands                                14
# Richmond                                     94
# Rosedale                                      4
# Ryerson                                     100
# South Niagara                                14
# St. James Town                              126
# Stn A PO Boxes 25 The Esplanade              98
# Toronto Dominion Centre                     100
# Toronto Islands                             100
# Underground city                            100
# Union Station                               100
# University of Toronto                        32
# Victoria Hotel                              100

# %%
print('There are {} uniques categories.'.format(len(downtown_toronto_venues['Venue Category'].unique())))
# Out:
# There are 206 uniques categories.

# %% [markdown]
# <h2>Get Central Toronto Venues</h2>

# %%
central_toronto_data = df[df['Borough'] == 'Central Toronto'].reset_index(drop=True)
central_toronto_venues = getNearbyVenues(names=central_toronto_data['Neighborhood'], latitudes=central_toronto_data['Latitude'], longitudes=central_toronto_data['Longitude'])

# %%
central_toronto_venues.head()
# Out:
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Lawrence Park              43.728020              -79.388790
# 1  Lawrence Park              43.728020              -79.388790
# 2  Lawrence Park              43.728020              -79.388790
# 3  Lawrence Park              43.728020              -79.388790
# 4       Roselawn              43.711695              -79.416936
#
#                             Venue  Venue Latitude  Venue Longitude  \
# 0            Lawrence Park Ravine       43.726963       -79.394382
# 1                 HYC Design Inc.       43.726793       -79.391681
# 2              Zodiac Swim School       43.728532       -79.382860
# 3  TTC Bus #162 - Lawrence-Donway       43.728026       -79.382805
# 4         Rosalind's Garden Oasis       43.712189       -79.411978
#
#      Venue Category
# 0              Park
# 1  Business Service
# 2       Swim School
# 3          Bus Line
# 4            Garden

# %%
central_toronto_venues.groupby('Neighborhood').count()
# Out:
#                     Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Davisville                             36                      36     36
# Davisville North                        9                       9      9
# Deer Park                              14                      14     14
# Forest Hill North                       4                       4      4
# Forest Hill SE                         14                      14     14
# Forest Hill West                        4                       4      4
# Lawrence Park                           4                       4      4
# Moore Park                              1                       1      1
# North Midtown                          20                      20     20
# North Toronto West                     19                      19     19
# Rathnelly                              14                      14     14
# Roselawn                                3                       3      3
# South Hill                             14                      14     14
# Summerhill East                         1                       1      1
# Summerhill West                        14                      14     14
# The Annex                              20                      20     20
# Yorkville                              20                      20     20
#
#                     Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Davisville                      36               36              36
# Davisville North                 9                9               9
# Deer Park                       14               14              14
# Forest Hill North                4                4               4
# Forest Hill SE                  14               14              14
# Forest Hill West                 4                4               4
# Lawrence Park                    4                4               4
# Moore Park                       1                1               1
# North Midtown                   20               20              20
# North Toronto West              19               19              19
# Rathnelly                       14               14              14
# Roselawn                         3                3               3
# South Hill                      14               14              14
# Summerhill East                  1                1               1
# Summerhill West                 14               14              14
# The Annex                       20               20              20
# Yorkville                       20               20              20

# %%
print('There are {} uniques categories.'.format(len(central_toronto_venues['Venue Category'].unique())))
# Out:
# There are 63 uniques categories.

# %% [markdown]
# <h2>Get East Toronto Venues</h2>

# %%
east_toronto_data = df[df['Borough'] == 'East Toronto'].reset_index(drop=True)
east_toronto_venues = getNearbyVenues(names=east_toronto_data['Neighborhood'], 
                                          latitudes=east_toronto_data['Latitude'], 
                                          longitudes=east_toronto_data['Longitude'])

# %%
east_toronto_venues.head()
# Out:
#         Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0        The Beaches              43.676357              -79.293031
# 1        The Beaches              43.676357              -79.293031
# 2        The Beaches              43.676357              -79.293031
# 3        The Beaches              43.676357              -79.293031
# 4  The Danforth West              43.679557              -79.352188
#
#                                 Venue  Venue Latitude  Venue Longitude  \
# 0                   Glen Manor Ravine       43.676821       -79.293942
# 1  The Big Carrot Natural Food Market       43.678879       -79.297734
# 2                 Grover Pub and Grub       43.679181       -79.297215
# 3                       Upper Beaches       43.680563       -79.292869
# 4                       MenEssentials       43.677820       -79.351265
#
#       Venue Category
# 0              Trail
# 1  Health Food Store
# 2                Pub
# 3       Neighborhood
# 4     Cosmetics Shop

# %%
east_toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                    Neighborhood Latitude  \
# Neighborhood
# Business Reply Mail Processing Centre 969 Eastern                     17
# India Bazaar                                                          20
# Riverdale                                                             42
# Studio District                                                       38
# The Beaches                                                            4
# The Beaches West                                                      20
# The Danforth West                                                     42
#
#                                                    Neighborhood Longitude  \
# Neighborhood
# Business Reply Mail Processing Centre 969 Eastern                      17
# India Bazaar                                                           20
# Riverdale                                                              42
# Studio District                                                        38
# The Beaches                                                             4
# The Beaches West                                                       20
# The Danforth West                                                      42
#
#                                                    Venue  Venue Latitude  \
# Neighborhood
# Business Reply Mail Processing Centre 969 Eastern     17              17
# India Bazaar                                          20              20
# Riverdale                                             42              42
# Studio District                                       38              38
# The Beaches                                            4               4
# The Beaches West                                      20              20
# The Danforth West                                     42              42
#
#                                                    Venue Longitude  \
# Neighborhood
# Business Reply Mail Processing Centre 969 Eastern               17
# India Bazaar                                                    20
# Riverdale                                                       42
# Studio District                                                 38
# The Beaches                                                      4
# The Beaches West                                                20
# The Danforth West                                               42
#
#                                                    Venue Category
# Neighborhood
# Business Reply Mail Processing Centre 969 Eastern              17
# India Bazaar                                                   20
# Riverdale                                                      42
# Studio District                                                38
# The Beaches                                                     4
# The Beaches West                                               20
# The Danforth West                                              42

# %%
print('There are {} uniques categories.'.format(len(east_toronto_venues['Venue Category'].unique())))
# Out:
# There are 68 uniques categories.

# %% [markdown]
# <h2>Get West Toronto Venues</h2>

# %%
west_toronto_data = df[df['Borough'] == 'West Toronto'].reset_index(drop=True)
west_toronto_venues = getNearbyVenues(names=west_toronto_data['Neighborhood'], 
                                          latitudes=west_toronto_data['Latitude'], 
                                          longitudes=west_toronto_data['Longitude'])

# %%
west_toronto_venues.head()
# Out:
#          Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Dovercourt Village              43.669005              -79.442259
# 1  Dovercourt Village              43.669005              -79.442259
# 2  Dovercourt Village              43.669005              -79.442259
# 3  Dovercourt Village              43.669005              -79.442259
# 4  Dovercourt Village              43.669005              -79.442259
#
#                      Venue  Venue Latitude  Venue Longitude  \
# 0     The Greater Good Bar       43.669409       -79.439267
# 1                 Parallel       43.669516       -79.438728
# 2                  FreshCo       43.667918       -79.440754
# 3   Blood Brothers Brewing       43.669944       -79.436533
# 4  Happy Bakery & Pastries       43.667050       -79.441791
#
#               Venue Category
# 0                        Bar
# 1  Middle Eastern Restaurant
# 2              Grocery Store
# 3                    Brewery
# 4                     Bakery

# %%
west_toronto_venues.groupby('Neighborhood').count()
# Out:
#                     Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Brockton                               24                      24     24
# Dovercourt Village                     16                      16     16
# Dufferin                               16                      16     16
# Exhibition Place                       24                      24     24
# High Park                              25                      25     25
# Little Portugal                        42                      42     42
# Parkdale                               15                      15     15
# Parkdale Village                       24                      24     24
# Roncesvalles                           15                      15     15
# Runnymede                              33                      33     33
# Swansea                                33                      33     33
# The Junction South                     25                      25     25
# Trinity                                42                      42     42
#
#                     Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Brockton                        24               24              24
# Dovercourt Village              16               16              16
# Dufferin                        16               16              16
# Exhibition Place                24               24              24
# High Park                       25               25              25
# Little Portugal                 42               42              42
# Parkdale                        15               15              15
# Parkdale Village                24               24              24
# Roncesvalles                    15               15              15
# Runnymede                       33               33              33
# Swansea                         33               33              33
# The Junction South              25               25              25
# Trinity                         42               42              42

# %%
print('There are {} uniques categories.'.format(len(west_toronto_venues['Venue Category'].unique())))
# Out:
# There are 80 uniques categories.

# %% [markdown]
# <h2>Concat All Borough</h2>

# %%
downtown_toronto_venues['Borough']='downtown toronto'
central_toronto_venues['Borough']='central toronto'
east_toronto_venues['Borough']='east toronto'
west_toronto_venues['Borough']='west toronto'

# %%
all_toronto_venues = pd.concat([downtown_toronto_venues, central_toronto_venues, east_toronto_venues, west_toronto_venues])

# %% [markdown]
# <h2>Analysis Each Neighborhood</h2>

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
def top_venues_sorted(num_top_venues, borough_grouped):
    indicators = ['st', 'nd', 'rd']

    # create columns according to number of top venues
    columns = ['Neighborhood']
    for ind in np.arange(num_top_venues):
        try:
            columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
        except:
            columns.append('{}th Most Common Venue'.format(ind+1))

    # create a new dataframe
    neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
    neighborhoods_venues_sorted['Neighborhood'] = borough_grouped['Neighborhood']

    for ind in np.arange(borough_grouped.shape[0]):
        neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(borough_grouped.iloc[ind, :], num_top_venues)

    return neighborhoods_venues_sorted

# %%
# one hot encoding
all_toronto_onehot = pd.get_dummies(all_toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
all_toronto_onehot['Neighborhood'] = all_toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [all_toronto_onehot.columns[-1]] + list(all_toronto_onehot.columns[:-1])
all_toronto_onehot = all_toronto_onehot[fixed_columns]

all_toronto_onehot.shape
# Out:
# (3018, 231)

# %%
all_toronto_grouped = all_toronto_onehot.groupby('Neighborhood').mean().reset_index()

# %%
all_toronto_neighborhoods_venues_sorted = top_venues_sorted(10, all_toronto_grouped)
all_toronto_neighborhoods_venues_sorted.shape
# Out:
# (73, 11)

# %% [markdown]
# <h2>Cluster Neighborhoods</h2>

# %%
k = 5

all_toronto_grouped_clustering = all_toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=k, random_state=0).fit(all_toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([3, 2, 3, 3, 3, 2, 3, 3, 3, 3])

# %%
# add clustering labels
all_toronto_neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

all_toronto_merged = df

# merge downtown_toronto_grouped with manhattan_data to add latitude/longitude for each neighborhood
all_toronto_merged = all_toronto_merged.join(all_toronto_neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

all_toronto_merged.head()
# Out:
#    Postal Code           Borough     Neighborhood   Latitude  Longitude  \
# 2          M5A  Downtown Toronto     Harbourfront  43.654260 -79.360636
# 5          M7A  Downtown Toronto     Queen's Park  43.662301 -79.389494
# 12         M5B  Downtown Toronto          Ryerson  43.657162 -79.378937
# 13         M5B  Downtown Toronto  Garden District  43.657162 -79.378937
# 26         M5C  Downtown Toronto   St. James Town  43.651494 -79.375418
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 2                3           Coffee Shop                Bakery
# 5                3           Coffee Shop      Sushi Restaurant
# 12               3        Clothing Store           Coffee Shop
# 13               3        Clothing Store           Coffee Shop
# 26               3           Coffee Shop                  Café
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 2                   Café                  Park                   Pub
# 5            Yoga Studio                  Café                   Bar
# 12        Cosmetics Shop   Japanese Restaurant                  Café
# 13        Cosmetics Shop   Japanese Restaurant                  Café
# 26            Restaurant                  Park    Italian Restaurant
#
#    6th Most Common Venue      7th Most Common Venue 8th Most Common Venue  \
# 2                Theater             Breakfast Spot            Restaurant
# 5               Beer Bar        Fried Chicken Joint         Smoothie Shop
# 12       Bubble Tea Shop  Middle Eastern Restaurant      Ramen Restaurant
# 13       Bubble Tea Shop  Middle Eastern Restaurant      Ramen Restaurant
# 26             Gastropub                     Bakery           Pizza Place
#
#    9th Most Common Venue 10th Most Common Venue
# 2         Cosmetics Shop                Brewery
# 5          Burrito Place     Mexican Restaurant
# 12     Electronics Store              Bookstore
# 13     Electronics Store              Bookstore
# 26          Cocktail Bar                  Hotel

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(all_toronto_merged['Latitude'], all_toronto_merged['Longitude'], all_toronto_merged['Neighborhood'], all_toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_c58375e412d24b0c85b0e7bc369909a5%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c58375e412d24b0c85b0e7bc369909a5%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c58375e412d24b0c85b0e7bc369909a5%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_c58375e412d24b0c85b0e7bc369909a5%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.6534817%2C-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# <h2>Examine Clusters</h2>

# %%
all_toronto_merged.loc[all_toronto_merged['Cluster Labels'] == 0, all_toronto_merged.columns[[1] + list(range(5, all_toronto_merged.shape[1]))]]
# Out:
#               Borough  Cluster Labels 1st Most Common Venue  \
# 35       East Toronto               0     Health Food Store
# 111   Central Toronto               0                  Park
# 121   Central Toronto               0                  Park
# 122   Central Toronto               0                  Park
# 182  Downtown Toronto               0                  Park
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 35                  Trail                   Pub           Yoga Studio
# 111              Bus Line      Business Service           Swim School
# 121                 Trail         Jewelry Store      Sushi Restaurant
# 122                 Trail         Jewelry Store      Sushi Restaurant
# 182            Playground                 Trail   Monument / Landmark
#
#     5th Most Common Venue            6th Most Common Venue  \
# 35    Monument / Landmark                     Liquor Store
# 111        Lingerie Store                           Lounge
# 121           Yoga Studio  Molecular Gastronomy Restaurant
# 122           Yoga Studio  Molecular Gastronomy Restaurant
# 182        Lingerie Store                     Liquor Store
#
#     7th Most Common Venue 8th Most Common Venue     9th Most Common Venue  \
# 35                 Lounge                Market       Martial Arts School
# 111                Market   Martial Arts School  Mediterranean Restaurant
# 121          Liquor Store                Lounge                    Market
# 122          Liquor Store                Lounge                    Market
# 182                Lounge                Market       Martial Arts School
#
#        10th Most Common Venue
# 35   Mediterranean Restaurant
# 111               Men's Store
# 121       Martial Arts School
# 122       Martial Arts School
# 182  Mediterranean Restaurant

# %%
all_toronto_merged.loc[all_toronto_merged['Cluster Labels'] == 1, all_toronto_merged.columns[[1] + list(range(5, all_toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 149  Central Toronto               1            Restaurant
# 150  Central Toronto               1            Restaurant
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 149   Moroccan Restaurant          Liquor Store                Lounge
# 150   Moroccan Restaurant          Liquor Store                Lounge
#
#     5th Most Common Venue 6th Most Common Venue     7th Most Common Venue  \
# 149                Market   Martial Arts School  Mediterranean Restaurant
# 150                Market   Martial Arts School  Mediterranean Restaurant
#
#     8th Most Common Venue 9th Most Common Venue     10th Most Common Venue
# 149           Men's Store    Mexican Restaurant  Middle Eastern Restaurant
# 150           Men's Store    Mexican Restaurant  Middle Eastern Restaurant

# %%
all_toronto_merged.loc[all_toronto_merged['Cluster Labels'] == 2, all_toronto_merged.columns[[1] + list(range(5, all_toronto_merged.shape[1]))]]
# Out:
#               Borough  Cluster Labels 1st Most Common Venue  \
# 163  Downtown Toronto               2       Airport Service
# 164  Downtown Toronto               2       Airport Service
# 165  Downtown Toronto               2       Airport Service
# 166  Downtown Toronto               2       Airport Service
# 167  Downtown Toronto               2       Airport Service
# 168  Downtown Toronto               2       Airport Service
# 169  Downtown Toronto               2       Airport Service
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 163           Coffee Shop               Airport    Airport Food Court
# 164           Coffee Shop               Airport    Airport Food Court
# 165           Coffee Shop               Airport    Airport Food Court
# 166           Coffee Shop               Airport    Airport Food Court
# 167           Coffee Shop               Airport    Airport Food Court
# 168           Coffee Shop               Airport    Airport Food Court
# 169           Coffee Shop               Airport    Airport Food Court
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 163          Airport Gate        Airport Lounge      Airport Terminal
# 164          Airport Gate        Airport Lounge      Airport Terminal
# 165          Airport Gate        Airport Lounge      Airport Terminal
# 166          Airport Gate        Airport Lounge      Airport Terminal
# 167          Airport Gate        Airport Lounge      Airport Terminal
# 168          Airport Gate        Airport Lounge      Airport Terminal
# 169          Airport Gate        Airport Lounge      Airport Terminal
#
#     8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 163       Harbor / Marina                   Bar    Rental Car Location
# 164       Harbor / Marina                   Bar    Rental Car Location
# 165       Harbor / Marina                   Bar    Rental Car Location
# 166       Harbor / Marina                   Bar    Rental Car Location
# 167       Harbor / Marina                   Bar    Rental Car Location
# 168       Harbor / Marina                   Bar    Rental Car Location
# 169       Harbor / Marina                   Bar    Rental Car Location

# %%
all_toronto_merged.loc[all_toronto_merged['Cluster Labels'] == 3, all_toronto_merged.columns[[1] + list(range(5, all_toronto_merged.shape[1]))]]
# Out:
#               Borough  Cluster Labels 1st Most Common Venue  \
# 2    Downtown Toronto               3           Coffee Shop
# 5    Downtown Toronto               3           Coffee Shop
# 12   Downtown Toronto               3        Clothing Store
# 13   Downtown Toronto               3        Clothing Store
# 26   Downtown Toronto               3           Coffee Shop
# 36   Downtown Toronto               3           Coffee Shop
# 40   Downtown Toronto               3           Coffee Shop
# 41   Downtown Toronto               3         Grocery Store
# 48   Downtown Toronto               3           Coffee Shop
# 49   Downtown Toronto               3           Coffee Shop
# 50   Downtown Toronto               3           Coffee Shop
# 51       West Toronto               3              Pharmacy
# 52       West Toronto               3              Pharmacy
# 60   Downtown Toronto               3           Coffee Shop
# 61   Downtown Toronto               3           Coffee Shop
# 62   Downtown Toronto               3           Coffee Shop
# 63       West Toronto               3                   Bar
# 64       West Toronto               3                   Bar
# 71       East Toronto               3      Greek Restaurant
# 72       East Toronto               3      Greek Restaurant
# 73   Downtown Toronto               3           Coffee Shop
# 74   Downtown Toronto               3           Coffee Shop
# 75       West Toronto               3             Nightclub
# 76       West Toronto               3             Nightclub
# 77       West Toronto               3             Nightclub
# 84       East Toronto               3                  Park
# 85       East Toronto               3                  Park
# 86   Downtown Toronto               3           Coffee Shop
# 87   Downtown Toronto               3           Coffee Shop
# 98       East Toronto               3           Coffee Shop
# 120   Central Toronto               3                   Gym
# 123      West Toronto               3    Mexican Restaurant
# 124      West Toronto               3    Mexican Restaurant
# 129   Central Toronto               3           Coffee Shop
# 130   Central Toronto               3                  Café
# 131   Central Toronto               3                  Café
# 132   Central Toronto               3                  Café
# 133      West Toronto               3        Breakfast Spot
# 134      West Toronto               3        Breakfast Spot
# 141   Central Toronto               3        Sandwich Place
# 142  Downtown Toronto               3                  Café
# 143  Downtown Toronto               3                  Café
# 144      West Toronto               3                  Café
# 145      West Toronto               3                  Café
# 151  Downtown Toronto               3                  Café
# 152  Downtown Toronto               3                  Café
# 153  Downtown Toronto               3                  Café
# 158   Central Toronto               3           Coffee Shop
# 159   Central Toronto               3           Coffee Shop
# 160   Central Toronto               3           Coffee Shop
# 161   Central Toronto               3           Coffee Shop
# 162   Central Toronto               3           Coffee Shop
# 183  Downtown Toronto               3           Coffee Shop
# 188  Downtown Toronto               3            Restaurant
# 189  Downtown Toronto               3           Coffee Shop
# 190  Downtown Toronto               3           Coffee Shop
# 191  Downtown Toronto               3           Coffee Shop
# 195  Downtown Toronto               3           Coffee Shop
# 196      East Toronto               3           Yoga Studio
#
#      2nd Most Common Venue          3rd Most Common Venue  \
# 2                   Bakery                           Café
# 5         Sushi Restaurant                    Yoga Studio
# 12             Coffee Shop                 Cosmetics Shop
# 13             Coffee Shop                 Cosmetics Shop
# 26                    Café                     Restaurant
# 36            Cocktail Bar                         Bakery
# 40          Sandwich Place             Italian Restaurant
# 41                    Café                           Park
# 48                    Café                     Restaurant
# 49                    Café                     Restaurant
# 50                    Café                     Restaurant
# 51                  Bakery                           Park
# 52                  Bakery                           Park
# 60                Aquarium                           Café
# 61                Aquarium                           Café
# 62                Aquarium                           Café
# 63        Asian Restaurant          Vietnamese Restaurant
# 64        Asian Restaurant          Vietnamese Restaurant
# 71             Coffee Shop             Italian Restaurant
# 72             Coffee Shop             Italian Restaurant
# 73                   Hotel                           Café
# 74                   Hotel                           Café
# 75                    Café                    Coffee Shop
# 76                    Café                    Coffee Shop
# 77                    Café                    Coffee Shop
# 84    Fast Food Restaurant                            Gym
# 85    Fast Food Restaurant                            Gym
# 86              Restaurant                          Hotel
# 87              Restaurant                          Hotel
# 98                 Brewery                         Bakery
# 120                  Hotel           Gym / Fitness Center
# 123                   Café                Thai Restaurant
# 124                   Café                Thai Restaurant
# 129         Clothing Store                    Yoga Studio
# 130         Sandwich Place                    Coffee Shop
# 131         Sandwich Place                    Coffee Shop
# 132         Sandwich Place                    Coffee Shop
# 133              Gift Shop                      Bookstore
# 134              Gift Shop                      Bookstore
# 141           Dessert Shop                    Pizza Place
# 142                 Bakery                            Bar
# 143                 Bakery                            Bar
# 144            Pizza Place               Sushi Restaurant
# 145            Pizza Place               Sushi Restaurant
# 151  Vietnamese Restaurant  Vegetarian / Vegan Restaurant
# 152  Vietnamese Restaurant  Vegetarian / Vegan Restaurant
# 153  Vietnamese Restaurant  Vegetarian / Vegan Restaurant
# 158             Bagel Shop             Light Rail Station
# 159             Bagel Shop             Light Rail Station
# 160             Bagel Shop             Light Rail Station
# 161             Bagel Shop             Light Rail Station
# 162             Bagel Shop             Light Rail Station
# 183           Cocktail Bar             Seafood Restaurant
# 188            Pizza Place                    Coffee Shop
# 189                   Café                     Restaurant
# 190                   Café                          Hotel
# 191                   Café                          Hotel
# 195    Japanese Restaurant               Sushi Restaurant
# 196          Garden Center                     Comic Shop
#
#              4th Most Common Venue        5th Most Common Venue  \
# 2                             Park                          Pub
# 5                             Café                          Bar
# 12             Japanese Restaurant                         Café
# 13             Japanese Restaurant                         Café
# 26                            Park           Italian Restaurant
# 36                        Pharmacy                     Beer Bar
# 40                            Café                  Salad Place
# 41                      Restaurant                  Candy Store
# 48                  Clothing Store                          Gym
# 49                  Clothing Store                          Gym
# 50                  Clothing Store                          Gym
# 51                     Coffee Shop             Recording Studio
# 52                     Coffee Shop             Recording Studio
# 60                           Hotel          Sporting Goods Shop
# 61                           Hotel          Sporting Goods Shop
# 62                           Hotel          Sporting Goods Shop
# 63   Vegetarian / Vegan Restaurant                         Café
# 64   Vegetarian / Vegan Restaurant                         Café
# 71                  Ice Cream Shop       Furniture / Home Store
# 72                  Ice Cream Shop       Furniture / Home Store
# 73              Seafood Restaurant           Italian Restaurant
# 74              Seafood Restaurant           Italian Restaurant
# 75                  Breakfast Spot                Grocery Store
# 76                  Breakfast Spot                Grocery Store
# 77                  Breakfast Spot                Grocery Store
# 84                             Pub                 Liquor Store
# 85                             Pub                 Liquor Store
# 86                            Café                          Gym
# 87                            Café                          Gym
# 98                            Café          American Restaurant
# 120                    Pizza Place             Department Store
# 123                  Grocery Store           Italian Restaurant
# 124                  Grocery Store           Italian Restaurant
# 129             Mexican Restaurant           Salon / Barbershop
# 130                    Pizza Place                 Burger Joint
# 131                    Pizza Place                 Burger Joint
# 132                    Pizza Place                 Burger Joint
# 133                   Dessert Shop  Eastern European Restaurant
# 134                   Dessert Shop  Eastern European Restaurant
# 141                            Gym                  Coffee Shop
# 142            Japanese Restaurant                    Bookstore
# 143            Japanese Restaurant                    Bookstore
# 144             Italian Restaurant                  Coffee Shop
# 145             Italian Restaurant                  Coffee Shop
# 151                    Coffee Shop                         Park
# 152                    Coffee Shop                         Park
# 153                    Coffee Shop                         Park
# 158            Fried Chicken Joint                  Supermarket
# 159            Fried Chicken Joint                  Supermarket
# 160            Fried Chicken Joint                  Supermarket
# 161            Fried Chicken Joint                  Supermarket
# 162            Fried Chicken Joint                  Supermarket
# 183                     Restaurant                         Café
# 188                           Café                         Park
# 189                           Park           Italian Restaurant
# 190                     Restaurant          Japanese Restaurant
# 191                     Restaurant          Japanese Restaurant
# 195                     Restaurant                      Gay Bar
# 196                    Pizza Place             Recording Studio
#
#     6th Most Common Venue      7th Most Common Venue  \
# 2                 Theater             Breakfast Spot
# 5                Beer Bar        Fried Chicken Joint
# 12        Bubble Tea Shop  Middle Eastern Restaurant
# 13        Bubble Tea Shop  Middle Eastern Restaurant
# 26              Gastropub                     Bakery
# 36         Farmers Market         Seafood Restaurant
# 40           Burger Joint            Bubble Tea Shop
# 41             Baby Store         Athletics & Sports
# 48          Deli / Bodega            Thai Restaurant
# 49          Deli / Bodega            Thai Restaurant
# 50          Deli / Bodega            Thai Restaurant
# 51            Music Venue                       Café
# 52            Music Venue                       Café
# 60         Scenic Lookout         Italian Restaurant
# 61         Scenic Lookout         Italian Restaurant
# 62         Scenic Lookout         Italian Restaurant
# 63             Restaurant                Men's Store
# 64             Restaurant                Men's Store
# 71            Yoga Studio            Bubble Tea Shop
# 72            Yoga Studio            Bubble Tea Shop
# 73    Japanese Restaurant                 Restaurant
# 74    Japanese Restaurant                 Restaurant
# 75     Italian Restaurant          Convenience Store
# 76     Italian Restaurant          Convenience Store
# 77     Italian Restaurant          Convenience Store
# 84      Fish & Chips Shop             Sandwich Place
# 85      Fish & Chips Shop             Sandwich Place
# 86     Italian Restaurant        American Restaurant
# 87     Italian Restaurant        American Restaurant
# 98              Gastropub    Comfort Food Restaurant
# 120        Sandwich Place             Breakfast Spot
# 123  Fast Food Restaurant  Cajun / Creole Restaurant
# 124  Fast Food Restaurant  Cajun / Creole Restaurant
# 129                   Spa        Sporting Goods Shop
# 130             BBQ Joint          Indian Restaurant
# 131             BBQ Joint          Indian Restaurant
# 132             BBQ Joint          Indian Restaurant
# 133         Movie Theater                        Bar
# 134         Movie Theater                        Bar
# 141                  Café         Italian Restaurant
# 142           Coffee Shop                   Beer Bar
# 143           Coffee Shop                   Beer Bar
# 144                   Pub                      Diner
# 145                   Pub                      Diner
# 151                   Bar                Gaming Cafe
# 152                   Bar                Gaming Cafe
# 153                   Bar                Gaming Cafe
# 158      Sushi Restaurant                       Bank
# 159      Sushi Restaurant                       Bank
# 160      Sushi Restaurant                       Bank
# 161      Sushi Restaurant                       Bank
# 162      Sushi Restaurant                       Bank
# 183                 Hotel                   Beer Bar
# 188                Bakery         Italian Restaurant
# 189             Gastropub                     Bakery
# 190                   Gym              Deli / Bodega
# 191                   Gym              Deli / Bodega
# 195  Fast Food Restaurant   Mediterranean Restaurant
# 196            Restaurant                    Butcher
#
#          8th Most Common Venue 9th Most Common Venue  \
# 2                   Restaurant        Cosmetics Shop
# 5                Smoothie Shop         Burrito Place
# 12            Ramen Restaurant     Electronics Store
# 13            Ramen Restaurant     Electronics Store
# 26                 Pizza Place          Cocktail Bar
# 36                 Cheese Shop            Restaurant
# 40            Department Store            Comic Shop
# 41                   Nightclub           Coffee Shop
# 48            Sushi Restaurant           Pizza Place
# 49            Sushi Restaurant           Pizza Place
# 50            Sushi Restaurant           Pizza Place
# 51   Middle Eastern Restaurant               Brewery
# 52   Middle Eastern Restaurant               Brewery
# 60                     Brewery   Fried Chicken Joint
# 61                     Brewery   Fried Chicken Joint
# 62                     Brewery   Fried Chicken Joint
# 63              Ice Cream Shop          Cocktail Bar
# 64              Ice Cream Shop          Cocktail Bar
# 71                        Café  Caribbean Restaurant
# 72                        Café  Caribbean Restaurant
# 73                 Salad Place        Breakfast Spot
# 74                 Salad Place        Breakfast Spot
# 75                Climbing Gym            Restaurant
# 76                Climbing Gym            Restaurant
# 77                Climbing Gym            Restaurant
# 84                  Restaurant            Steakhouse
# 85                  Restaurant            Steakhouse
# 86          Seafood Restaurant         Deli / Bodega
# 87          Seafood Restaurant         Deli / Bodega
# 98           Convenience Store       Coworking Space
# 120          Food & Drink Shop                  Park
# 123                       Park             Bookstore
# 124                       Park             Bookstore
# 129                       Café            Restaurant
# 130                        Pub           Flower Shop
# 131                        Pub           Flower Shop
# 132                        Pub           Flower Shop
# 133                       Bank            Restaurant
# 134                       Bank            Restaurant
# 141            Thai Restaurant      Sushi Restaurant
# 142                 Beer Store        Sandwich Place
# 143                 Beer Store        Sandwich Place
# 144              Burrito Place        Sandwich Place
# 145              Burrito Place        Sandwich Place
# 151               Burger Joint   Arts & Crafts Store
# 152               Burger Joint   Arts & Crafts Store
# 153               Burger Joint   Arts & Crafts Store
# 158                 Restaurant                   Pub
# 159                 Restaurant                   Pub
# 160                 Restaurant                   Pub
# 161                 Restaurant                   Pub
# 162                 Restaurant                   Pub
# 183        Japanese Restaurant                Bakery
# 188                        Pub  Caribbean Restaurant
# 189                Pizza Place          Cocktail Bar
# 190                 Steakhouse      Asian Restaurant
# 191                 Steakhouse      Asian Restaurant
# 195                Men's Store                   Pub
# 196              Burrito Place        Farmers Market
#
#         10th Most Common Venue
# 2                      Brewery
# 5           Mexican Restaurant
# 12                   Bookstore
# 13                   Bookstore
# 26                       Hotel
# 36                    Fountain
# 40                       Diner
# 41          Italian Restaurant
# 48                  Steakhouse
# 49                  Steakhouse
# 50                  Steakhouse
# 51                Liquor Store
# 52                Liquor Store
# 60                  Restaurant
# 61                  Restaurant
# 62                  Restaurant
# 63                 Coffee Shop
# 64                 Coffee Shop
# 71              Cosmetics Shop
# 72              Cosmetics Shop
# 73                   Gastropub
# 74                   Gastropub
# 75               Burrito Place
# 76               Burrito Place
# 77               Burrito Place
# 84          Italian Restaurant
# 85          Italian Restaurant
# 86                Cocktail Bar
# 87                Cocktail Bar
# 98                 Music Store
# 120                   Hospital
# 123                  Speakeasy
# 124                  Speakeasy
# 129        Rental Car Location
# 130  Middle Eastern Restaurant
# 131  Middle Eastern Restaurant
# 132  Middle Eastern Restaurant
# 133                    Dog Run
# 134                    Dog Run
# 141           Indoor Play Area
# 142                 Restaurant
# 143                 Restaurant
# 144                 Restaurant
# 145                 Restaurant
# 151         Mexican Restaurant
# 152         Mexican Restaurant
# 153         Mexican Restaurant
# 158               Liquor Store
# 159               Liquor Store
# 160               Liquor Store
# 161               Liquor Store
# 162               Liquor Store
# 183         Italian Restaurant
# 188                Snack Place
# 189                      Hotel
# 190         Seafood Restaurant
# 191         Seafood Restaurant
# 195                Yoga Studio
# 196                    Brewery

# %%
all_toronto_merged.loc[all_toronto_merged['Cluster Labels'] == 4, all_toronto_merged.columns[[1] + list(range(5, all_toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 112  Central Toronto               4          Home Service
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 112                Garden        Ice Cream Shop           Yoga Studio
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 112   Moroccan Restaurant                Lounge                Market
#
#     8th Most Common Venue     9th Most Common Venue 10th Most Common Venue
# 112   Martial Arts School  Mediterranean Restaurant            Men's Store
